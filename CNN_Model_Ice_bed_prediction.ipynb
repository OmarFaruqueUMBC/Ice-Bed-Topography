# %% [markdown]
# #Ice Bed Height Prediction Using CNN Model
#
# This notebook used the CNN based deep learning model to predict ice bed height using 5 variables ['surf_vx', 'surf_vy', 'surf_elv', 'surf_dhdt', 'surf_SMB']. Here both the old data and new interpolated data are used for prediction. The CNN model is trained using training data and tested on testing data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
import h5py
import xarray as xr
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import tree
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def rmspe(y_true, y_pred):
    return np.sqrt(np.nanmean(np.square(((y_true - y_pred) / y_true))))*100

# %%
def rmspe_1(y_true, y_pred):
    return np.sqrt(np.nanmean(np.square(y_true - y_pred) / y_true))*100

# %% [markdown]
# ## Old Data

# %%
df_train=pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/train.csv')
df_test=pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/test.csv')
df_pred=pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/y_test.csv')
data_1201=pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/df_1201.csv')

# %%
df_test
# Out:
#           surf_x     surf_y     surf_vx    surf_vy   surf_elv  surf_dhdt  \
# 0      -220025.0 -1697525.0  -81.467440   0.913897  1862.4003  -0.003780
# 1      -220025.0 -1697675.0  -81.488320   1.039868  1862.3989  -0.003897
# 2      -220025.0 -1697825.0  -81.496080   1.172581  1862.3975  -0.004014
# 3      -220025.0 -1697975.0  -81.490715   1.312036  1862.3961  -0.004131
# 4      -220025.0 -1698125.0  -81.514725   1.292812  1862.3948  -0.004248
# ...          ...        ...         ...        ...        ...        ...
# 235967 -241925.0 -1871675.0 -109.031784  30.579424  1556.2831  -0.412165
# 235968 -241925.0 -1871675.0 -109.031784  30.579424  1556.2831  -0.412165
# 235969 -241925.0 -1871675.0 -109.031784  30.579424  1556.2831  -0.412165
# 235970 -242075.0 -1871375.0 -111.202000  31.286001  1555.5704  -0.418871
# 235971 -242075.0 -1871375.0 -111.202000  31.286001  1555.5704  -0.418871
#
#         surf_SMB  track_bed_test_x  track_bed_test_y
# 0       0.374366    -220038.295520     -1.697568e+06
# 1       0.374305    -220038.408158     -1.697642e+06
# 2       0.374243    -220038.646540     -1.697789e+06
# 3       0.374181    -220038.939782     -1.697936e+06
# 4       0.374117    -220039.334272     -1.698083e+06
# ...          ...               ...               ...
# 235967 -0.018388    -241867.395118     -1.871682e+06
# 235968 -0.018388    -241879.313090     -1.871664e+06
# 235969 -0.018388    -241890.904137     -1.871645e+06
# 235970 -0.016968    -242055.253924     -1.871391e+06
# 235971 -0.016968    -242066.841155     -1.871373e+06
#
# [235972 rows x 9 columns]

# %%
data_1201
# Out:
#          Unnamed: 0    surf_x     surf_y     surf_vx   surf_vy  surf_dhdt  \
# 0                 0 -278075.0 -1697525.0 -117.986570  8.049935  -0.362801
# 1                 1 -278075.0 -1697675.0 -118.086580  8.429934  -0.363170
# 2                 2 -278075.0 -1697825.0 -118.103740  8.865048  -0.363538
# 3                 3 -278075.0 -1697975.0 -118.038060  9.355281  -0.363907
# 4                 4 -278075.0 -1698125.0 -117.793236  9.596583  -0.364276
# ...             ...       ...        ...         ...       ...        ...
# 1442396     1442396  -98075.0 -1876925.0  -16.739680  7.869811   0.005050
# 1442397     1442397  -98075.0 -1877075.0  -16.679783  7.903055   0.004754
# 1442398     1442398  -98075.0 -1877225.0  -16.616787  7.968928   0.004459
# 1442399     1442399  -98075.0 -1877375.0  -16.527618  8.169706   0.004163
# 1442400     1442400  -98075.0 -1877525.0  -16.438242  8.345219   0.003867
#
#          surf_SMB   surf_elv
# 0        0.102309  1348.6687
# 1        0.100127  1347.2958
# 2        0.098367  1346.9690
# 3        0.096918  1346.1609
# 4        0.095606  1345.8989
# ...           ...        ...
# 1442396  0.332106  2530.5593
# 1442397  0.332474  2530.5574
# 1442398  0.332817  2530.5554
# 1442399  0.333154  2530.5535
# 1442400  0.333492  2530.3570
#
# [1442401 rows x 8 columns]

# %%
df_test_only_reading=df_test.drop(['track_bed_test_x','track_bed_test_y','surf_x', 'surf_y'],axis=1)
df_train_only_reading=df_train.drop(['track_bed_x','track_bed_y','surf_x', 'surf_y'],axis=1)
test_data_1201=data_1201.drop(['Unnamed: 0','surf_x', 'surf_y'],axis=1)
test_data_1201_ordered = test_data_1201[['surf_vx', 'surf_vy', 'surf_elv', 'surf_dhdt', 'surf_SMB']]

# %%
df_test_only_reading.keys(), df_train_only_reading.keys(), test_data_1201_ordered.keys()
# Out:
# (Index(['surf_vx', 'surf_vy', 'surf_elv', 'surf_dhdt', 'surf_SMB'], dtype='object'),
#  Index(['surf_vx', 'surf_vy', 'surf_elv', 'surf_dhdt', 'surf_SMB',
#         'track_bed_target'],
#        dtype='object'),
#  Index(['surf_vx', 'surf_vy', 'surf_elv', 'surf_dhdt', 'surf_SMB'], dtype='object'))

# %%
x1_train=df_train_only_reading.iloc[:,:-1]
y1_train=df_train_only_reading.iloc[:,-1:]
X_test_given=df_test_only_reading.iloc[:,:]
Y_test_given=df_pred.iloc[:,:]

# %% [markdown]
# ### Plot dataset before normalization:

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = ['surf_vx', 'surf_vy', 'surf_elv', 'surf_dhdt', 'surf_SMB']

#MultipleBoxplot
plt.figure(figsize=(20,6))

plt.subplot(1, 3, 1)
plt.ylim([-700, 2700])
plt.boxplot(x1_train, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : Training Data')


plt.subplot(1, 3, 2)
plt.ylim([-700, 2700])
plt.boxplot(X_test_given, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : Testing Data')


plt.subplot(1, 3, 3)
plt.ylim([-700, 2700])
plt.boxplot(test_data_1201_ordered, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : 1201x1201 Grid Data')

plt.tight_layout()
plt.show()

# %%
x1_train.shape, X_test_given.shape, test_data_1201_ordered.shape
# Out:
# ((396734, 5), (235972, 5), (1442401, 5))

# %%
all_X = np.concatenate((x1_train, X_test_given, test_data_1201_ordered), axis=0)
all_X.shape
# Out:
# (2075107, 5)

# %%
y1_train.shape, Y_test_given.shape
# Out:
# ((396734, 1), (235972, 1))

# %%
all_Y = np.concatenate((y1_train, Y_test_given), axis=0)
all_Y.shape
# Out:
# (632706, 1)

# %% [markdown]
# ### Normalize dataset to bring all variables in the range of [0, 1]:

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_Y = MinMaxScaler(feature_range=(0, 1))

all_X_nor = scaler_X.fit_transform(all_X)
all_Y_nor = scaler_Y.fit_transform(all_Y)

# %%
all_X_nor.shape, all_Y_nor.shape
# Out:
# ((2075107, 5), (632706, 1))

# %%
#seperate the dependent and independent variable for train, test, and 1201 dataset
data_train_X = all_X_nor[0:396734, :]
data_train_Y = all_Y_nor[0:396734, :]
data_test_X = all_X_nor[396734:632706, :]
data_test_Y = all_Y_nor[396734:, :]
data_1201_X = all_X_nor[632706:, :]

# %% [markdown]
# ### Plot dataset after normalization:

# %%
#pd.DataFrame.from_records(data_train_X).boxplot(), pd.DataFrame.from_records(data_test_X).boxplot(), pd.DataFrame.from_records(data_1201_X).boxplot()

import numpy as np
import matplotlib.pyplot as plt

labels = ['surf_vx', 'surf_vy', 'surf_elv', 'surf_dhdt', 'surf_SMB']

#MultipleBoxplot
plt.figure(figsize=(20,6))

plt.subplot(1, 3, 1)
plt.ylim([-0.1, 1.1])
plt.boxplot(data_train_X, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : Training Data')


plt.subplot(1, 3, 2)
plt.ylim([-0.1, 1.1])
plt.boxplot(data_test_X, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : Testing Data')


plt.subplot(1, 3, 3)
plt.ylim([-0.1, 1.1])
plt.boxplot(data_1201_X, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : 1201x1201 Grid Data')


plt.tight_layout()
plt.show()

# %%
data_train_X_1D = data_train_X.reshape(data_train_X.shape[0], data_train_X.shape[1], 1)
data_test_X_1D = data_test_X.reshape(data_test_X.shape[0], data_test_X.shape[1], 1)
data_1201_X_1D = data_1201_X.reshape(data_1201_X.shape[0], data_1201_X.shape[1], 1)

# %%
from numpy.random import seed
seed(13)

# %% [markdown]
# ### Training model using old data

# %%
import keras,os
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten, Dropout, AveragePooling2D, LSTM, Activation, ConvLSTM2D, TimeDistributed, Input, Reshape
from keras.layers import UpSampling1D, Conv2DTranspose, UpSampling2D, BatchNormalization, Conv1D, MaxPooling1D

def get_model(input_dims):
  input_batch = Input(shape = input_dims)

  conv_model = Conv1D(filters=512, kernel_size=2, strides=1,padding='same', activation=keras.layers.LeakyReLU(alpha=0.05))(input_batch) #input_shape=(5)
  conv_model = Conv1D(filters=512, kernel_size=2, strides=1,padding='same', activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Dropout(0.5)(conv_model)
  conv_model = Conv1D(filters=256, kernel_size=2, strides=1,padding='same', activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Conv1D(filters=256, kernel_size=2, strides=1,padding='same',activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Dropout(0.5)(conv_model)
  conv_model = Conv1D(filters=128, kernel_size=2, strides=1,padding='same', activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Conv1D(filters=128, kernel_size=2, strides=1,padding='same',activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Dropout(0.5)(conv_model)
  conv_model = Conv1D(filters=64, kernel_size=2, strides=1,padding='same', activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Conv1D(filters=64, kernel_size=2, strides=1,padding='same',activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Dropout(0.5)(conv_model)
  conv_model = Conv1D(filters=32, kernel_size=2, strides=1,padding='same',activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Conv1D(filters=32, kernel_size=2, strides=1,padding='same', activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Dropout(0.5)(conv_model)
  conv_model = Flatten()(conv_model)
  conv_model = keras.layers.Dense(32, activation='relu', name='Dense1')(conv_model)
  conv_model = keras.layers.Dense(1, activation='linear', name='Dense2')(conv_model)

  encoder = Model(inputs=input_batch, outputs=conv_model, name='encoder')

  return encoder

# %%
model = get_model(data_train_X_1D.shape[1:])
model.summary()
model.compile(optimizer='adam', loss='mse')
model.fit(data_train_X_1D, y=data_train_Y, epochs=100, batch_size=5000, verbose=1,  validation_split =0.3, shuffle=True)
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 5, 1)]            0
#
#  conv1d_30 (Conv1D)          (None, 5, 512)            1536
#
#  conv1d_31 (Conv1D)          (None, 5, 512)            524800
#
#  dropout_15 (Dropout)        (None, 5, 512)            0
#
#  conv1d_32 (Conv1D)          (None, 5, 256)            262400
#
#  conv1d_33 (Conv1D)          (None, 5, 256)            131328
#
#  dropout_16 (Dropout)        (None, 5, 256)            0
#
#  conv1d_34 (Conv1D)          (None, 5, 128)            65664
#
#  conv1d_35 (Conv1D)          (None, 5, 128)            32896
#
#  dropout_17 (Dropout)        (None, 5, 128)            0
#
#  conv1d_36 (Conv1D)          (None, 5, 64)             16448
#
#  conv1d_37 (Conv1D)          (None, 5, 64)             8256
#
#  dropout_18 (Dropout)        (None, 5, 64)             0
#
#  conv1d_38 (Conv1D)          (None, 5, 32)             4128
#
#  conv1d_39 (Conv1D)          (None, 5, 32)             2080
#
#  dropout_19 (Dropout)        (None, 5, 32)             0
#
#  flatten_3 (Flatten)         (None, 160)               0
#
#  Dense1 (Dense)              (None, 32)                5152
#
#  Dense2 (Dense)              (None, 1)                 33
#
# =================================================================
# Total params: 1,054,721
# Trainable params: 1,054,721
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 56/56 [==============================] - 10s 105ms/step - loss: 0.0283 - val_loss: 0.0069
# Epoch 2/100
# 56/56 [==============================] - 6s 114ms/step - loss: 0.0080 - val_loss: 0.0067
# Epoch 3/100
# 56/56 [==============================] - 6s 114ms/step - loss: 0.0072 - val_loss: 0.0059
# Epoch 4/100
# 56/56 [==============================] - 6s 116ms/step - loss: 0.0058 - val_loss: 0.0047
# Epoch 5/100
# 56/56 [==============================] - 6s 101ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 6/100
# 56/56 [==============================] - 6s 102ms/step - loss: 0.0039 - val_loss: 0.0031
# Epoch 7/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0035 - val_loss: 0.0028
# Epoch 8/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0032 - val_loss: 0.0028
# Epoch 9/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 10/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0028 - val_loss: 0.0023
# Epoch 11/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 12/100
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 13/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0024 - val_loss: 0.0021
# Epoch 14/100
# 56/56 [==============================] - 5s 98ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 15/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 16/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 17/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 18/100
# 56/56 [==============================] - 6s 101ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 19/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 20/100
# 56/56 [==============================] - 6s 101ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 21/100
# 56/56 [==============================] - 6s 101ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 22/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 23/100
# 56/56 [==============================] - 6s 101ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 24/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 25/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 26/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 27/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 28/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 29/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 30/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 31/100
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 32/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 33/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 34/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 35/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 36/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 37/100
# 56/56 [==============================] - 6s 112ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 38/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 39/100
# 56/56 [==============================] - 6s 112ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 40/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 41/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 42/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 43/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 44/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 45/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 46/100
# 56/56 [==============================] - 6s 112ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 47/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 48/100
# 56/56 [==============================] - 6s 112ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 49/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 50/100
# 56/56 [==============================] - 6s 101ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 51/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 52/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 53/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 54/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 55/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 56/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 57/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 58/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 59/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 60/100
# 56/56 [==============================] - 6s 112ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 61/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 62/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 63/100
# 56/56 [==============================] - 6s 110ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 64/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 65/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 66/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 67/100
# 56/56 [==============================] - 6s 112ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 68/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 69/100
# 56/56 [==============================] - 6s 112ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 70/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 71/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 72/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 73/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 74/100
# 56/56 [==============================] - 6s 112ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 75/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 76/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 77/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 78/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 79/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 80/100
# 56/56 [==============================] - 6s 112ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 81/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 82/100
# 56/56 [==============================] - 6s 101ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 83/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 84/100
# 56/56 [==============================] - 6s 111ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 85/100
# 56/56 [==============================] - 6s 101ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 86/100
# 56/56 [==============================] - 6s 99ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 87/100
# 56/56 [==============================] - 6s 100ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 88/100
# 56/56 [==============================] - 6s 99ms/step - loss: 9.9702e-04 - val_loss: 0.0013
# Epoch 89/100
# 56/56 [==============================] - 6s 100ms/step - loss: 9.8951e-04 - val_loss: 0.0012
# Epoch 90/100
# 56/56 [==============================] - 6s 111ms/step - loss: 9.9945e-04 - val_loss: 0.0012
# Epoch 91/100
# 56/56 [==============================] - 6s 111ms/step - loss: 9.9641e-04 - val_loss: 0.0012
# Epoch 92/100
# 56/56 [==============================] - 6s 100ms/step - loss: 9.9218e-04 - val_loss: 0.0013
# Epoch 93/100
# 56/56 [==============================] - 6s 99ms/step - loss: 9.8842e-04 - val_loss: 0.0012
# Epoch 94/100
# 56/56 [==============================] - 6s 100ms/step - loss: 9.9707e-04 - val_loss: 0.0012
# Epoch 95/100
# 56/56 [==============================] - 6s 99ms/step - loss: 9.8922e-04 - val_loss: 0.0012
# Epoch 96/100
# 56/56 [==============================] - 6s 100ms/step - loss: 9.9378e-04 - val_loss: 0.0013
# Epoch 97/100
# 56/56 [==============================] - 6s 100ms/step - loss: 9.7624e-04 - val_loss: 0.0013
# Epoch 98/100
# 56/56 [==============================] - 6s 111ms/step - loss: 9.6212e-04 - val_loss: 0.0013
# Epoch 99/100
# 56/56 [==============================] - 6s 101ms/step - loss: 9.6042e-04 - val_loss: 0.0013
# Epoch 100/100
# 56/56 [==============================] - 6s 100ms/step - loss: 9.5543e-04 - val_loss: 0.0012

# %% [markdown]
# ####Prediction of the track bed on training data

# %%
y_pred_train = model.predict(data_train_X_1D)
# Out:
# 12398/12398 [==============================] - 32s 3ms/step

# %%
y_pred_train.shape, data_train_Y.shape
# Out:
# ((396734, 1), (396734, 1))

# %%
train_Predict_full_range = scaler_Y.inverse_transform(y_pred_train)
data_train_Y_full_range = scaler_Y.inverse_transform(data_train_Y)

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error

print('RMSE:',np.sqrt(mean_squared_error(data_train_Y_full_range, train_Predict_full_range)))
print('RMSE Percentage:',rmspe(data_train_Y_full_range, train_Predict_full_range))
print('RMSE Percentage-1:',rmspe_1(data_train_Y_full_range, train_Predict_full_range))
print('Mean Absolute Error:', mean_absolute_error(data_train_Y_full_range, train_Predict_full_range))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(data_train_Y_full_range, train_Predict_full_range))
print('R^2 Score:', r2_score(data_train_Y_full_range, train_Predict_full_range))
# Out:
# RMSE: 77.00341705212655
# RMSE Percentage: 6116.848465047879
# RMSE Percentage-1: 350.2856792404823
# Mean Absolute Error: 53.527836292172616
# Mean Absolute Percentage Error: 1.245101635753192
# R^2 Score: 0.837092027867604

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error

print('RMSE:',np.sqrt(mean_squared_error(data_train_Y_full_range, train_Predict_full_range)))
print('RMSE Percentage:',rmspe(data_train_Y_full_range, train_Predict_full_range))
print('RMSE Percentage-1:',rmspe_1(data_train_Y_full_range, train_Predict_full_range))
print('Mean Absolute Error:', mean_absolute_error(data_train_Y_full_range, train_Predict_full_range))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(data_train_Y_full_range, train_Predict_full_range))
print('R^2 Score:', r2_score(data_train_Y_full_range, train_Predict_full_range))
# Out:
# RMSE: 77.60901815269575
# RMSE Percentage: 6734.261830255592
# RMSE Percentage-1: 324.2831847156741
# Mean Absolute Error: 53.9732393249342
# Mean Absolute Percentage Error: 1.3094516734542712
# R^2 Score: 0.8345195395049582

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error

print('RMSE:',np.sqrt(mean_squared_error(data_train_Y_full_range, train_Predict_full_range)))
print('RMSE Percentage:',rmspe(data_train_Y_full_range, train_Predict_full_range))
print('RMSE Percentage-1:',rmspe_1(data_train_Y_full_range, train_Predict_full_range))
print('Mean Absolute Error:', mean_absolute_error(data_train_Y_full_range, train_Predict_full_range))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(data_train_Y_full_range, train_Predict_full_range))
print('R^2 Score:', r2_score(data_train_Y_full_range, train_Predict_full_range))
# Out:
# RMSE: 91.29630881926903
# RMSE Percentage: 7870.0986582246405
# RMSE Percentage-1: 773.3721872199912
# Mean Absolute Error: 65.80499407993166
# Mean Absolute Percentage Error: 1.3159205956998783
# R^2 Score: 0.7710035337608446

# %%
import matplotlib.pyplot as plt

plt.subplots(figsize=(15, 5))

plt.plot(data_train_Y_full_range, color='red', label="Ground Truth") # Y_test_given,y_pred_test
plt.plot(train_Predict_full_range, color='blue', label="Prediction")
plt.ylabel("Ice Bed Height")
plt.xlabel("Data Elements")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ####Prediction of track bed on test data

# %%
y_predict_test = model.predict(data_test_X_1D)
# Out:
# 7375/7375 [==============================] - 17s 2ms/step

# %%
data_test_Y.shape, y_predict_test.shape
# Out:
# ((235972, 1), (235972, 1))

# %%
test_Predict_full_range = scaler_Y.inverse_transform(y_predict_test)
data_test_Y_full_range = scaler_Y.inverse_transform(data_test_Y)

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error

print('RMSE:',np.sqrt(mean_squared_error(data_test_Y_full_range, test_Predict_full_range)))
print('RMSE Percentage:',rmspe(data_test_Y_full_range, test_Predict_full_range))
print('RMSE Percentage-1:',rmspe_1(data_test_Y_full_range, test_Predict_full_range))
print('Mean Absolute Error:', mean_absolute_error(data_test_Y_full_range, test_Predict_full_range))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(data_test_Y_full_range, test_Predict_full_range))
print('R^2 Score:', r2_score(data_test_Y_full_range, test_Predict_full_range))
# Out:
# RMSE: 153.65159238458608
# RMSE Percentage: 15088.680649374584
# RMSE Percentage-1: 234.75432338399074
# Mean Absolute Error: 108.04312921208573
# Mean Absolute Percentage Error: 1.7059676676078155
# R^2 Score: -0.11662863545172142

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error

print('RMSE:',np.sqrt(mean_squared_error(data_test_Y_full_range, test_Predict_full_range)))
print('RMSE Percentage:',rmspe(data_test_Y_full_range, test_Predict_full_range))
print('RMSE Percentage-1:',rmspe_1(data_test_Y_full_range, test_Predict_full_range))
print('Mean Absolute Error:', mean_absolute_error(data_test_Y_full_range, test_Predict_full_range))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(data_test_Y_full_range, test_Predict_full_range))
print('R^2 Score:', r2_score(data_test_Y_full_range, test_Predict_full_range))
# Out:
# RMSE: 140.7234360946213
# RMSE Percentage: 14427.003904287727
# RMSE Percentage-1: nan
# Mean Absolute Error: 96.6343143211534
# Mean Absolute Percentage Error: 1.6621348677049048
# R^2 Score: 0.06337123402773392
# <ipython-input-4-aa62cd6b9d47>:2: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.nanmean(np.square(y_true - y_pred) / y_true))*100

# %%
import matplotlib.pyplot as plt

plt.subplots(figsize=(15, 5))

plt.plot(data_test_Y_full_range, color='red', label="Ground Truth") # Y_test_given,y_pred_test
plt.plot(test_Predict_full_range, color='blue', label="Prediction")
plt.ylabel("Ice Bed Height")
plt.xlabel("Data Elements")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# #### Prediction of ice bed height on 1201x1201 grid data

# %%
y_Predict_1201 = model.predict(data_1201_X_1D)
# Out:
# 45076/45076 [==============================] - 105s 2ms/step

# %%
y_Predict_1201.shape
# Out:
# (1442401, 1)

# %%
y_Predict_1201_full = scaler_Y.inverse_transform(y_Predict_1201)

# %%
y_Predict_1201_full_flatten=y_Predict_1201_full.flatten()

# %%
prediction_on_1201_2D=y_Predict_1201_full_flatten.reshape(1201,1201)
prediction_on_1201_2D.shape
# Out:
# (1201, 1201)

# %%
new_filename_2 = '/content/drive/MyDrive/Ice-bed_dataset/ice_bed_prediction_1201_Dense_LSTM.h5'

with h5py.File(new_filename_2, 'w') as hf:
    hf.create_dataset("track bed prediction",  data=prediction_on_1201_2D)

# %%
import matplotlib.pyplot as plt
plt.imshow(np.transpose(prediction_on_1201_2D), cmap="jet")

plt.title('Track Bed Prediction')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.gca().invert_yaxis()
plt.colorbar(label="Color-bar", orientation="horizontal")

# %%
import matplotlib.pyplot as plt
plt.imshow(np.transpose(prediction_on_1201_2D), cmap="jet")
#plt.imshow(a.squeeze(), cmap="seismic", interpolation="nearest") # new interpolated data
plt.title('Track Bed Prediction')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.gca().invert_yaxis()
plt.colorbar(label="Color-bar", orientation="horizontal")

# %% [markdown]
# ## New Interpolation Data

# %%
n_training_data = pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/new_interpolated_track_bed_training.csv')
n_testing_data = pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/new_interpotaled_track_bed_testing.csv')
n_df_pred = pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/y_test.csv')
n_data_1201 = pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/df_1201.csv')
n_test_data_1201 = n_data_1201.drop(['Unnamed: 0','surf_x', 'surf_y'],axis=1)

# %%
n_training_data
# Out:
#         Unnamed: 0         surf_x       surf_y  track_bed_target     surf_vx  \
# 0                0 -206037.406250 -1827384.000        538.235168 -102.379379
# 1                1 -205981.171875 -1827518.625        550.491638 -101.973237
# 2                2 -205953.109375 -1827586.125        563.800598 -101.784982
# 3                3 -205897.078125 -1827720.750        560.530823 -101.493970
# 4                4 -205841.328125 -1827855.625        545.708252 -101.271730
# ...            ...            ...          ...               ...         ...
# 396729      396729 -278061.656250 -1720043.625        240.890564 -105.011937
# 396730      396730 -278064.468750 -1720023.125        240.956131 -105.014680
# 396731      396731 -278067.125000 -1720001.375        233.992737 -105.020867
# 396732      396732 -278069.656250 -1719980.875        227.039673 -105.026963
# 396733      396733 -278072.343750 -1719959.250        227.064072 -105.033698
#
#          surf_vy  surf_dhdt  surf_SMB     surf_elv
# 0       2.455286  -0.197761  0.300519  1873.835128
# 1       2.884405  -0.197749  0.300364  1874.221764
# 2       2.952367  -0.197750  0.300285  1874.520200
# 3       2.288839  -0.197765  0.300125  1874.620712
# 4       1.235018  -0.197797  0.299963  1875.128108
# ...          ...        ...       ...          ...
# 396729 -4.932849  -0.403757  0.144332  1347.292140
# 396730 -4.937994  -0.403847  0.144088  1347.204583
# 396731 -4.940966  -0.403939  0.143831  1347.069799
# 396732 -4.945610  -0.404026  0.143588  1346.941386
# 396733 -4.952594  -0.404118  0.143332  1346.804583
#
# [396734 rows x 9 columns]

# %%
n_testing_data
# Out:
#         Unnamed: 0         surf_x        surf_y     surf_vx    surf_vy  \
# 0                0 -220038.295520 -1.697568e+06  -81.469318   1.026504
# 1                1 -220038.408158 -1.697642e+06  -81.479483   1.088446
# 2                2 -220038.646540 -1.697789e+06  -81.490122   1.216577
# 3                3 -220038.939782 -1.697936e+06  -81.488490   1.350560
# 4                4 -220039.334272 -1.698083e+06  -81.506943   1.358371
# ...            ...            ...           ...         ...        ...
# 235967      235967 -241867.395118 -1.871682e+06 -109.036689  30.657134
# 235968      235968 -241879.313090 -1.871664e+06 -109.227077  30.716942
# 235969      235969 -241890.904137 -1.871645e+06 -109.397180  30.763926
# 235970      235970 -242055.253924 -1.871391e+06 -111.142185  31.286631
# 235971      235971 -242066.841155 -1.871373e+06 -111.234107  31.316871
#
#         surf_dhdt  surf_SMB     surf_elv
# 0       -0.003840  0.374337  1862.341442
# 1       -0.003898  0.374307  1862.340283
# 2       -0.004015  0.374246  1862.337831
# 3       -0.004132  0.374184  1862.310339
# 4       -0.004249  0.374122  1862.314235
# ...           ...       ...          ...
# 235967  -0.411423 -0.017839  1556.905320
# 235968  -0.411860 -0.017826  1556.788316
# 235969  -0.412292 -0.017803  1556.660822
# 235970  -0.418384 -0.016967  1555.680990
# 235971  -0.418821 -0.016881  1555.653762
#
# [235972 rows x 8 columns]

# %%
n_training_data = n_training_data.drop(['Unnamed: 0','surf_x', 'surf_y'],axis=1)
n_testing_data = n_testing_data.drop(['Unnamed: 0','surf_x', 'surf_y'],axis=1)

# %%
n_training_data.shape, n_testing_data.shape, n_test_data_1201.shape
# Out:
# ((396734, 6), (235972, 5), (1442401, 5))

# %%
n_training_data.keys(), n_testing_data.keys(), n_test_data_1201.keys()
# Out:
# (Index(['track_bed_target', 'surf_vx', 'surf_vy', 'surf_dhdt', 'surf_SMB',
#         'surf_elv'],
#        dtype='object'),
#  Index(['surf_vx', 'surf_vy', 'surf_dhdt', 'surf_SMB', 'surf_elv'], dtype='object'),
#  Index(['surf_vx', 'surf_vy', 'surf_dhdt', 'surf_SMB', 'surf_elv'], dtype='object'))

# %%
n_x1_train = n_training_data.iloc[:,1:]
n_y1_train = n_training_data.iloc[:,0:1]
n_X_test_given = n_testing_data.iloc[:,:]
n_Y_test_given = n_df_pred.iloc[:,:]

# %% [markdown]
# ### Plot dataset before normalization:

# %%
#n_x1_train.boxplot(), n_X_test_given.boxplot(), n_test_data_1201.boxplot()

import numpy as np
import matplotlib.pyplot as plt

labels = ['surf_vx', 'surf_vy', 'surf_dhdt', 'surf_SMB', 'surf_elv']

#MultipleBoxplot
plt.figure(figsize=(20,6))

plt.subplot(1, 3, 1)
plt.ylim([-700, 2700])
plt.boxplot(n_x1_train, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : New Training Data')


plt.subplot(1, 3, 2)
plt.ylim([-700, 2700])
plt.boxplot(n_X_test_given, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : New Testing Data')


plt.subplot(1, 3, 3)
plt.ylim([-700, 2700])
plt.boxplot(n_test_data_1201, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : 1201x1201 Grid Data')

plt.tight_layout()
plt.show()

# %%
n_x1_train.shape, n_X_test_given.shape, n_test_data_1201.shape
# Out:
# ((396734, 5), (235972, 5), (1442401, 5))

# %%
n_all_X = np.concatenate((n_x1_train, n_X_test_given, n_test_data_1201), axis=0)
n_all_X.shape
# Out:
# (2075107, 5)

# %%
n_y1_train.shape, n_Y_test_given.shape
# Out:
# ((396734, 1), (235972, 1))

# %%
n_all_Y = np.concatenate((n_y1_train, n_Y_test_given), axis=0)
n_all_Y.shape
# Out:
# (632706, 1)

# %% [markdown]
# ### Normalize dataset to bring all variables in the range of [0, 1]:

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_Y = MinMaxScaler(feature_range=(0, 1))

n_all_X_nor = scaler_X.fit_transform(n_all_X)
n_all_Y_nor = scaler_Y.fit_transform(n_all_Y)

# %%
n_all_X_nor.shape, n_all_Y_nor.shape
# Out:
# ((2075107, 5), (632706, 1))

# %%
#seperate the dependent and independent variable for train, test, and 1201 dataset
n_data_train_X = n_all_X_nor[0:396734, :]
n_data_train_Y = n_all_Y_nor[0:396734, :]
n_data_test_X = n_all_X_nor[396734:632706, :]
n_data_test_Y = n_all_Y_nor[396734:, :]
n_data_1201_X = n_all_X_nor[632706:, :]

# %% [markdown]
# ### Plot dataset after normalization:

# %%
#pd.DataFrame.from_records(n_data_train_X).boxplot(), pd.DataFrame.from_records(n_data_test_X).boxplot(), pd.DataFrame.from_records(n_data_1201_X).boxplot()

import numpy as np
import matplotlib.pyplot as plt

labels = ['surf_vx', 'surf_vy', 'surf_dhdt', 'surf_SMB', 'surf_elv']

#MultipleBoxplot
plt.figure(figsize=(20,6))

plt.subplot(1, 3, 1)
plt.ylim([-0.1, 1.1])
plt.boxplot(n_data_train_X, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : New Training Data')


plt.subplot(1, 3, 2)
plt.ylim([-0.1, 1.1])
plt.boxplot(n_data_test_X, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : New Testing Data')


plt.subplot(1, 3, 3)
plt.ylim([-0.1, 1.1])
plt.boxplot(n_data_1201_X, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : 1201x1201 Grid Data')


plt.tight_layout()
plt.show()

# %%
n_data_train_X_1D = n_data_train_X.reshape(n_data_train_X.shape[0], n_data_train_X.shape[1], 1)
n_data_test_X_1D = n_data_test_X.reshape(n_data_test_X.shape[0], n_data_test_X.shape[1], 1)
n_data_1201_X_1D = n_data_1201_X.reshape(n_data_1201_X.shape[0], n_data_1201_X.shape[1], 1)

# %%
from numpy.random import seed
seed(13)

# %% [markdown]
# ### Training model using new interpolation data

# %%
import keras,os
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten, Dropout, AveragePooling2D, LSTM, Activation, ConvLSTM2D, TimeDistributed, Input, Reshape
from keras.layers import UpSampling1D, Conv2DTranspose, UpSampling2D, BatchNormalization, Conv1D, MaxPooling1D

def get_model(input_dims):
  input_batch = Input(shape = input_dims)

  conv_model = Conv1D(filters=512, kernel_size=2, strides=1,padding='same', activation=keras.layers.LeakyReLU(alpha=0.05))(input_batch) #input_shape=(5)
  conv_model = Conv1D(filters=512, kernel_size=2, strides=1,padding='same', activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Dropout(0.5)(conv_model)
  conv_model = Conv1D(filters=256, kernel_size=2, strides=1,padding='same', activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Conv1D(filters=256, kernel_size=2, strides=1,padding='same',activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Dropout(0.5)(conv_model)
  conv_model = Conv1D(filters=128, kernel_size=2, strides=1,padding='same', activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Conv1D(filters=128, kernel_size=2, strides=1,padding='same',activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Dropout(0.5)(conv_model)
  conv_model = Conv1D(filters=64, kernel_size=2, strides=1,padding='same', activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Conv1D(filters=64, kernel_size=2, strides=1,padding='same',activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Dropout(0.5)(conv_model)
  conv_model = Conv1D(filters=32, kernel_size=2, strides=1,padding='same',activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Conv1D(filters=32, kernel_size=2, strides=1,padding='same', activation=keras.layers.LeakyReLU(alpha=0.05))(conv_model)
  conv_model = Dropout(0.5)(conv_model)
  conv_model = Flatten()(conv_model)
  conv_model = keras.layers.Dense(32, activation='relu', name='Dense1')(conv_model)
  conv_model = keras.layers.Dense(1, activation='linear', name='Dense2')(conv_model)

  encoder = Model(inputs=input_batch, outputs=conv_model, name='encoder')

  return encoder

# %%
n_model = get_model(n_data_train_X_1D.shape[1:])
n_model.summary()
n_model.compile(optimizer='adam', loss='mse')
n_model.fit(n_data_train_X_1D, y=n_data_train_Y, epochs=100, batch_size=5000, verbose=1, validation_split =0.2, shuffle=True)
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 5, 1)]            0
#
#  conv1d_50 (Conv1D)          (None, 5, 512)            1536
#
#  conv1d_51 (Conv1D)          (None, 5, 512)            524800
#
#  dropout_25 (Dropout)        (None, 5, 512)            0
#
#  conv1d_52 (Conv1D)          (None, 5, 256)            262400
#
#  conv1d_53 (Conv1D)          (None, 5, 256)            131328
#
#  dropout_26 (Dropout)        (None, 5, 256)            0
#
#  conv1d_54 (Conv1D)          (None, 5, 128)            65664
#
#  conv1d_55 (Conv1D)          (None, 5, 128)            32896
#
#  dropout_27 (Dropout)        (None, 5, 128)            0
#
#  conv1d_56 (Conv1D)          (None, 5, 64)             16448
#
#  conv1d_57 (Conv1D)          (None, 5, 64)             8256
#
#  dropout_28 (Dropout)        (None, 5, 64)             0
#
#  conv1d_58 (Conv1D)          (None, 5, 32)             4128
#
#  conv1d_59 (Conv1D)          (None, 5, 32)             2080
#
#  dropout_29 (Dropout)        (None, 5, 32)             0
#
#  flatten_5 (Flatten)         (None, 160)               0
#
#  Dense1 (Dense)              (None, 32)                5152
#
#  Dense2 (Dense)              (None, 1)                 33
#
# =================================================================
# Total params: 1,054,721
# Trainable params: 1,054,721
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 64/64 [==============================] - 14s 158ms/step - loss: 0.0213 - val_loss: 0.0075
# Epoch 2/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0075 - val_loss: 0.0074
# Epoch 3/100
# 64/64 [==============================] - 6s 99ms/step - loss: 0.0062 - val_loss: 0.0056
# Epoch 4/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 5/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0042 - val_loss: 0.0043
# Epoch 6/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0037 - val_loss: 0.0044
# Epoch 7/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 8/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 9/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 10/100
# 64/64 [==============================] - 6s 93ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 11/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 12/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 13/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 14/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 15/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 16/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 17/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 18/100
# 64/64 [==============================] - 6s 99ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 19/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 20/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 21/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 22/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 23/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 24/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 25/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 26/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 27/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 28/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 29/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 30/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 31/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 32/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 33/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 34/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 35/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 36/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 37/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 38/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 39/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 40/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 41/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 42/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 43/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 44/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 45/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 46/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 47/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 48/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 49/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 50/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 51/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 52/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 53/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 54/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 55/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 56/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 57/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 58/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 59/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 60/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 61/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 62/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 63/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 64/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 65/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 66/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 67/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 68/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 69/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 70/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 71/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 72/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 73/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 74/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 75/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 76/100
# 64/64 [==============================] - 6s 97ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 77/100
# 64/64 [==============================] - 6s 98ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 78/100
# 64/64 [==============================] - 6s 94ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 79/100
# 64/64 [==============================] - 6s 95ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 80/100
# 64/64 [==============================] - 6s 97ms/step - loss: 9.8161e-04 - val_loss: 0.0015
# Epoch 81/100
# 64/64 [==============================] - 6s 94ms/step - loss: 9.7684e-04 - val_loss: 0.0015
# Epoch 82/100
# 64/64 [==============================] - 6s 95ms/step - loss: 9.8931e-04 - val_loss: 0.0015
# Epoch 83/100
# 64/64 [==============================] - 6s 97ms/step - loss: 9.7650e-04 - val_loss: 0.0016
# Epoch 84/100
# 64/64 [==============================] - 6s 95ms/step - loss: 9.6456e-04 - val_loss: 0.0016
# Epoch 85/100
# 64/64 [==============================] - 6s 97ms/step - loss: 9.7024e-04 - val_loss: 0.0015
# Epoch 86/100
# 64/64 [==============================] - 6s 95ms/step - loss: 9.6772e-04 - val_loss: 0.0015
# Epoch 87/100
# 64/64 [==============================] - 6s 97ms/step - loss: 9.3617e-04 - val_loss: 0.0015
# Epoch 88/100
# 64/64 [==============================] - 6s 95ms/step - loss: 9.4781e-04 - val_loss: 0.0015
# Epoch 89/100
# 64/64 [==============================] - 6s 97ms/step - loss: 9.5682e-04 - val_loss: 0.0015
# Epoch 90/100
# 64/64 [==============================] - 6s 95ms/step - loss: 9.3011e-04 - val_loss: 0.0017
# Epoch 91/100
# 64/64 [==============================] - 6s 94ms/step - loss: 9.6270e-04 - val_loss: 0.0016
# Epoch 92/100
# 64/64 [==============================] - 6s 95ms/step - loss: 9.5548e-04 - val_loss: 0.0016
# Epoch 93/100
# 64/64 [==============================] - 6s 95ms/step - loss: 9.3558e-04 - val_loss: 0.0015
# Epoch 94/100
# 64/64 [==============================] - 6s 94ms/step - loss: 9.2808e-04 - val_loss: 0.0015
# Epoch 95/100
# 64/64 [==============================] - 6s 98ms/step - loss: 9.0321e-04 - val_loss: 0.0015
# Epoch 96/100
# 64/64 [==============================] - 6s 97ms/step - loss: 8.9428e-04 - val_loss: 0.0016
# Epoch 97/100
# 64/64 [==============================] - 6s 98ms/step - loss: 9.0347e-04 - val_loss: 0.0015
# Epoch 98/100
# 64/64 [==============================] - 6s 94ms/step - loss: 9.0557e-04 - val_loss: 0.0015
# Epoch 99/100
# 64/64 [==============================] - 6s 98ms/step - loss: 8.8623e-04 - val_loss: 0.0015
# Epoch 100/100
# 64/64 [==============================] - 6s 94ms/step - loss: 9.0245e-04 - val_loss: 0.0016

# %% [markdown]
# ####Prediction of the track bed on new training data

# %%
n_y_pred_train = n_model.predict(n_data_train_X_1D)
# Out:
# 12398/12398 [==============================] - 30s 2ms/step

# %%
n_y_pred_train.shape, n_data_train_Y.shape
# Out:
# ((396734, 1), (396734, 1))

# %%
n_train_Predict_full_range = scaler_Y.inverse_transform(n_y_pred_train)
n_data_train_Y_full_range = scaler_Y.inverse_transform(n_data_train_Y)

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error

print('RMSE:',np.sqrt(mean_squared_error(n_data_train_Y_full_range, n_train_Predict_full_range)))
print('RMSE Percentage:',rmspe(n_data_train_Y_full_range, n_train_Predict_full_range))
print('RMSE Percentage-1:',rmspe_1(n_data_train_Y_full_range, n_train_Predict_full_range))
print('Mean Absolute Error:', mean_absolute_error(n_data_train_Y_full_range, n_train_Predict_full_range))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(n_data_train_Y_full_range, n_train_Predict_full_range))
print('R^2 Score:', r2_score(n_data_train_Y_full_range, n_train_Predict_full_range))
# Out:
# RMSE: 83.0244462459323
# RMSE Percentage: 7833.936881683894
# RMSE Percentage-1: 323.41233609307085
# Mean Absolute Error: 56.58832866172762
# Mean Absolute Percentage Error: 1.5420839925999539
# R^2 Score: 0.8106199103559221

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error

print('RMSE:',np.sqrt(mean_squared_error(n_data_train_Y_full_range, n_train_Predict_full_range)))
print('RMSE Percentage:',rmspe(n_data_train_Y_full_range, n_train_Predict_full_range))
print('RMSE Percentage-1:',rmspe_1(n_data_train_Y_full_range, n_train_Predict_full_range))
print('Mean Absolute Error:', mean_absolute_error(n_data_train_Y_full_range, n_train_Predict_full_range))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(n_data_train_Y_full_range, n_train_Predict_full_range))
print('R^2 Score:', r2_score(n_data_train_Y_full_range, n_train_Predict_full_range))
# Out:
# RMSE: 93.6254691260372
# RMSE Percentage: 6546.162663726497
# RMSE Percentage-1: 642.4190694247202
# Mean Absolute Error: 65.36402491278668
# Mean Absolute Percentage Error: 1.4522404909535744
# R^2 Score: 0.7591701272726801

# %%
import matplotlib.pyplot as plt

plt.subplots(figsize=(15, 5))

plt.plot(n_data_train_Y_full_range, color='red', label="Ground Truth") # Y_test_given,y_pred_test
plt.plot(n_train_Predict_full_range, color='blue', label="Prediction")
plt.ylabel("Ice Bed Height")
plt.xlabel("Data Elements")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ####Prediction of track bed on new test data

# %%
n_y_predict_test = n_model.predict(n_data_test_X_1D)
# Out:
# 7375/7375 [==============================] - 16s 2ms/step

# %%
n_data_test_Y.shape, n_y_predict_test.shape
# Out:
# ((235972, 1), (235972, 1))

# %%
n_test_Predict_full_range = scaler_Y.inverse_transform(n_y_predict_test)
n_data_test_Y_full_range = scaler_Y.inverse_transform(n_data_test_Y)

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error

print('RMSE:',np.sqrt(mean_squared_error(n_data_test_Y_full_range, n_test_Predict_full_range)))
print('RMSE Percentage:',rmspe(n_data_test_Y_full_range, n_test_Predict_full_range))
print('RMSE Percentage-1:',rmspe_1(n_data_test_Y_full_range, n_test_Predict_full_range))
print('Mean Absolute Error:', mean_absolute_error(n_data_test_Y_full_range, n_test_Predict_full_range))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(n_data_test_Y_full_range, n_test_Predict_full_range))
print('R^2 Score:', r2_score(n_data_test_Y_full_range, n_test_Predict_full_range))
# Out:
# RMSE: 150.7922101801557
# RMSE Percentage: 15067.920358587375
# RMSE Percentage-1: 146.46842623655363
# Mean Absolute Error: 103.72399468289669
# Mean Absolute Percentage Error: 1.7730572888233735
# R^2 Score: -0.07545549652086758

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error

print('RMSE:',np.sqrt(mean_squared_error(n_data_test_Y_full_range, n_test_Predict_full_range)))
print('RMSE Percentage:',rmspe(n_data_test_Y_full_range, n_test_Predict_full_range))
print('RMSE Percentage-1:',rmspe_1(n_data_test_Y_full_range, n_test_Predict_full_range))
print('Mean Absolute Error:', mean_absolute_error(n_data_test_Y_full_range, n_test_Predict_full_range))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(n_data_test_Y_full_range, n_test_Predict_full_range))
print('R^2 Score:', r2_score(n_data_test_Y_full_range, n_test_Predict_full_range))
# Out:
# RMSE: 148.92673621835766
# RMSE Percentage: 14938.338309215638
# RMSE Percentage-1: nan
# Mean Absolute Error: 101.70869430129619
# Mean Absolute Percentage Error: 1.7783824048304024
# R^2 Score: -0.04901083462328515
# <ipython-input-4-aa62cd6b9d47>:2: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.nanmean(np.square(y_true - y_pred) / y_true))*100

# %%
import matplotlib.pyplot as plt

plt.subplots(figsize=(15, 5))

plt.plot(n_data_test_Y_full_range, color='red', label="Ground Truth") # Y_test_given,y_pred_test
plt.plot(n_test_Predict_full_range, color='blue', label="Prediction")
plt.ylabel("Ice Bed Height")
plt.xlabel("Data Elements")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# #### Prediction of ice bed height on 1201x1201 grid data

# %%
n_y_Predict_1201 = n_model.predict(n_data_1201_X_1D)
# Out:
# 45076/45076 [==============================] - 107s 2ms/step

# %%
n_y_Predict_1201.shape
# Out:
# (1442401, 1)

# %%
n_y_Predict_1201_full = scaler_Y.inverse_transform(n_y_Predict_1201)

# %%
n_y_Predict_1201_full_flatten=n_y_Predict_1201_full.flatten()

# %%
n_prediction_on_1201_2D=n_y_Predict_1201_full_flatten.reshape(1201,1201)
n_prediction_on_1201_2D.shape
# Out:
# (1201, 1201)

# %%
new_filename_2 = '/content/drive/MyDrive/Ice-bed_dataset/ice_bed_prediction_1201_Dense_LSTM_new.h5'

with h5py.File(new_filename_2, 'w') as hf:
    hf.create_dataset("track bed prediction",  data=n_prediction_on_1201_2D)

# %%
import matplotlib.pyplot as plt
plt.imshow(np.transpose(n_prediction_on_1201_2D), cmap="jet")
#plt.imshow(a.squeeze(), cmap="seismic", interpolation="nearest") # new interpolated data
plt.title('Track Bed Prediction')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.gca().invert_yaxis()
plt.colorbar(label="Color-bar", orientation="horizontal")

# %%
import matplotlib.pyplot as plt
plt.imshow(np.transpose(n_prediction_on_1201_2D), cmap="seismic")
#plt.imshow(a.squeeze(), cmap="seismic", interpolation="nearest") # new interpolated data
plt.title('Track Bed Prediction')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.colorbar(label="Color-bar", orientation="horizontal")
