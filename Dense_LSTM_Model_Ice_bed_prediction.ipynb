# %% [markdown]
# #Ice Bed Height Prediction Using Dense-LSTM Model
#
# This notebook used the Dense and LSTM based deep learning model to predict ice bed height using 5 variables ['surf_vx', 'surf_vy', 'surf_elv', 'surf_dhdt', 'surf_SMB']. Here both the old data and new interpolated data are used for prediction. The Dense-LSTM model is trained using training data and tested on testing data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
import h5py
import xarray as xr
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import tree
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def rmspe(y_true, y_pred):
    return np.sqrt(np.nanmean(np.square(((y_true - y_pred) / y_true))))*100

# %%
def rmspe_1(y_true, y_pred):
    return np.sqrt(np.nanmean(np.square(y_true - y_pred) / y_true))*100

# %% [markdown]
# ## Old Data

# %%
df_train=pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/train.csv')
df_test=pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/test.csv')
df_pred=pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/y_test.csv')
data_1201=pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/df_1201.csv')

# %%
df_test
# Out:
#           surf_x     surf_y     surf_vx    surf_vy   surf_elv  surf_dhdt  \
# 0      -220025.0 -1697525.0  -81.467440   0.913897  1862.4003  -0.003780
# 1      -220025.0 -1697675.0  -81.488320   1.039868  1862.3989  -0.003897
# 2      -220025.0 -1697825.0  -81.496080   1.172581  1862.3975  -0.004014
# 3      -220025.0 -1697975.0  -81.490715   1.312036  1862.3961  -0.004131
# 4      -220025.0 -1698125.0  -81.514725   1.292812  1862.3948  -0.004248
# ...          ...        ...         ...        ...        ...        ...
# 235967 -241925.0 -1871675.0 -109.031784  30.579424  1556.2831  -0.412165
# 235968 -241925.0 -1871675.0 -109.031784  30.579424  1556.2831  -0.412165
# 235969 -241925.0 -1871675.0 -109.031784  30.579424  1556.2831  -0.412165
# 235970 -242075.0 -1871375.0 -111.202000  31.286001  1555.5704  -0.418871
# 235971 -242075.0 -1871375.0 -111.202000  31.286001  1555.5704  -0.418871
#
#         surf_SMB  track_bed_test_x  track_bed_test_y
# 0       0.374366    -220038.295520     -1.697568e+06
# 1       0.374305    -220038.408158     -1.697642e+06
# 2       0.374243    -220038.646540     -1.697789e+06
# 3       0.374181    -220038.939782     -1.697936e+06
# 4       0.374117    -220039.334272     -1.698083e+06
# ...          ...               ...               ...
# 235967 -0.018388    -241867.395118     -1.871682e+06
# 235968 -0.018388    -241879.313090     -1.871664e+06
# 235969 -0.018388    -241890.904137     -1.871645e+06
# 235970 -0.016968    -242055.253924     -1.871391e+06
# 235971 -0.016968    -242066.841155     -1.871373e+06
#
# [235972 rows x 9 columns]

# %%
data_1201
# Out:
#          Unnamed: 0    surf_x     surf_y     surf_vx   surf_vy  surf_dhdt  \
# 0                 0 -278075.0 -1697525.0 -117.986570  8.049935  -0.362801
# 1                 1 -278075.0 -1697675.0 -118.086580  8.429934  -0.363170
# 2                 2 -278075.0 -1697825.0 -118.103740  8.865048  -0.363538
# 3                 3 -278075.0 -1697975.0 -118.038060  9.355281  -0.363907
# 4                 4 -278075.0 -1698125.0 -117.793236  9.596583  -0.364276
# ...             ...       ...        ...         ...       ...        ...
# 1442396     1442396  -98075.0 -1876925.0  -16.739680  7.869811   0.005050
# 1442397     1442397  -98075.0 -1877075.0  -16.679783  7.903055   0.004754
# 1442398     1442398  -98075.0 -1877225.0  -16.616787  7.968928   0.004459
# 1442399     1442399  -98075.0 -1877375.0  -16.527618  8.169706   0.004163
# 1442400     1442400  -98075.0 -1877525.0  -16.438242  8.345219   0.003867
#
#          surf_SMB   surf_elv
# 0        0.102309  1348.6687
# 1        0.100127  1347.2958
# 2        0.098367  1346.9690
# 3        0.096918  1346.1609
# 4        0.095606  1345.8989
# ...           ...        ...
# 1442396  0.332106  2530.5593
# 1442397  0.332474  2530.5574
# 1442398  0.332817  2530.5554
# 1442399  0.333154  2530.5535
# 1442400  0.333492  2530.3570
#
# [1442401 rows x 8 columns]

# %%
df_test_only_reading=df_test.drop(['track_bed_test_x','track_bed_test_y','surf_x', 'surf_y'],axis=1)
df_train_only_reading=df_train.drop(['track_bed_x','track_bed_y','surf_x', 'surf_y'],axis=1)
test_data_1201=data_1201.drop(['Unnamed: 0','surf_x', 'surf_y'],axis=1)
test_data_1201_ordered = test_data_1201[['surf_vx', 'surf_vy', 'surf_elv', 'surf_dhdt', 'surf_SMB']]

# %%
df_test_only_reading.keys(), df_train_only_reading.keys(), test_data_1201_ordered.keys()
# Out:
# (Index(['surf_vx', 'surf_vy', 'surf_elv', 'surf_dhdt', 'surf_SMB'], dtype='object'),
#  Index(['surf_vx', 'surf_vy', 'surf_elv', 'surf_dhdt', 'surf_SMB',
#         'track_bed_target'],
#        dtype='object'),
#  Index(['surf_vx', 'surf_vy', 'surf_elv', 'surf_dhdt', 'surf_SMB'], dtype='object'))

# %%
x1_train=df_train_only_reading.iloc[:,:-1]
y1_train=df_train_only_reading.iloc[:,-1:]
X_test_given=df_test_only_reading.iloc[:,:]
Y_test_given=df_pred.iloc[:,:]

# %% [markdown]
# ### Plot dataset before normalization:

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = ['surf_vx', 'surf_vy', 'surf_elv', 'surf_dhdt', 'surf_SMB']

#MultipleBoxplot
plt.figure(figsize=(20,6))

plt.subplot(1, 3, 1)
plt.ylim([-700, 2700])
plt.boxplot(x1_train, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : Training Data')


plt.subplot(1, 3, 2)
plt.ylim([-700, 2700])
plt.boxplot(X_test_given, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : Testing Data')


plt.subplot(1, 3, 3)
plt.ylim([-700, 2700])
plt.boxplot(test_data_1201_ordered, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : 1201x1201 Grid Data')

plt.tight_layout()
plt.show()

# %%
x1_train.shape, X_test_given.shape, test_data_1201_ordered.shape
# Out:
# ((396734, 5), (235972, 5), (1442401, 5))

# %%
all_X = np.concatenate((x1_train, X_test_given, test_data_1201_ordered), axis=0)
all_X.shape
# Out:
# (2075107, 5)

# %%
y1_train.shape, Y_test_given.shape
# Out:
# ((396734, 1), (235972, 1))

# %%
all_Y = np.concatenate((y1_train, Y_test_given), axis=0)
all_Y.shape
# Out:
# (632706, 1)

# %% [markdown]
# ### Normalize dataset to bring all variables in the range of [0, 1]:

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_Y = MinMaxScaler(feature_range=(0, 1))

all_X_nor = scaler_X.fit_transform(all_X)
all_Y_nor = scaler_Y.fit_transform(all_Y)

# %%
all_X_nor.shape, all_Y_nor.shape
# Out:
# ((2075107, 5), (632706, 1))

# %%
#seperate the dependent and independent variable for train, test, and 1201 dataset
data_train_X = all_X_nor[0:396734, :]
data_train_Y = all_Y_nor[0:396734, :]
data_test_X = all_X_nor[396734:632706, :]
data_test_Y = all_Y_nor[396734:, :]
data_1201_X = all_X_nor[632706:, :]

# %% [markdown]
# ### Plot dataset after normalization:

# %%
#pd.DataFrame.from_records(data_train_X).boxplot(), pd.DataFrame.from_records(data_test_X).boxplot(), pd.DataFrame.from_records(data_1201_X).boxplot()

import numpy as np
import matplotlib.pyplot as plt

labels = ['surf_vx', 'surf_vy', 'surf_elv', 'surf_dhdt', 'surf_SMB']

#MultipleBoxplot
plt.figure(figsize=(20,6))

plt.subplot(1, 3, 1)
plt.ylim([-0.1, 1.1])
plt.boxplot(data_train_X, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : Training Data')


plt.subplot(1, 3, 2)
plt.ylim([-0.1, 1.1])
plt.boxplot(data_test_X, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : Testing Data')


plt.subplot(1, 3, 3)
plt.ylim([-0.1, 1.1])
plt.boxplot(data_1201_X, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : 1201x1201 Grid Data')


plt.tight_layout()
plt.show()

# %%
data_train_X_lstm = data_train_X.reshape(data_train_X.shape[0], 1, data_train_X.shape[1])
data_train_X_lstm.shape
# Out:
# (396734, 1, 5)

# %%
data_test_X_lstm = data_test_X.reshape(data_test_X.shape[0], 1, data_test_X.shape[1])
data_test_X_lstm.shape
# Out:
# (235972, 1, 5)

# %%
data_1201_X_lstm = data_1201_X.reshape(data_1201_X.shape[0], 1, data_1201_X.shape[1])
data_1201_X_lstm.shape
# Out:
# (1442401, 1, 5)

# %% [markdown]
# ### Training model using old data

# %%
import keras,os
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten, Dropout, AveragePooling2D, LSTM, Activation, ConvLSTM2D, TimeDistributed, Input, Reshape
from keras.layers import UpSampling1D, Conv2DTranspose, UpSampling2D, BatchNormalization
from tensorflow.keras import callbacks
import numpy as np

def get_model(input_dims):
  input_batch = Input(shape = input_dims)

  conv_model = TimeDistributed(Dense(128, activation="sigmoid"), name='ConvL1')(input_batch)
  conv_model = TimeDistributed(BatchNormalization())(conv_model)
  conv_model = TimeDistributed(Dense(128, activation="sigmoid"), name='ConvL2' )(conv_model)
  conv_model = TimeDistributed(BatchNormalization())(conv_model)
  conv_model = TimeDistributed(Dropout(0.5))(conv_model)
  conv_model = TimeDistributed(Dense(64, activation="sigmoid"), name='ConvL3' )(conv_model)
  conv_model = TimeDistributed(BatchNormalization())(conv_model)
  conv_model = TimeDistributed(Dense(64, activation="sigmoid"), name='ConvL4' )(conv_model)
  conv_model = TimeDistributed(BatchNormalization())(conv_model)
  conv_model = TimeDistributed(Dropout(0.5))(conv_model)
  conv_model = TimeDistributed(Dense(32, activation="sigmoid"), name='ConvL5' )(conv_model)
  conv_model = TimeDistributed(BatchNormalization())(conv_model)
  conv_model = TimeDistributed(Dense(32, activation="sigmoid"), name='ConvL6' )(conv_model)
  conv_model = TimeDistributed(BatchNormalization())(conv_model)
  conv_model = TimeDistributed(Dropout(0.5))(conv_model)

  lstm_network = LSTM(64, return_sequences=True)(conv_model)
  lstm_network = keras.layers.LSTM(32, return_sequences=False)(lstm_network)
  lstm_network = Dropout(0.5)(lstm_network)
  lstm_network = keras.layers.Dense(32, activation='sigmoid', name='Dense1')(lstm_network)
  lstm_network = keras.layers.Dense(1, activation='linear', name='Dense2')(lstm_network)

  encoder = Model(inputs=input_batch, outputs=lstm_network, name='encoder')

  return encoder

# %%
model = get_model(data_train_X_lstm.shape[1:])
model.summary()
model.compile(optimizer='adam', loss='mse')
model.fit(data_train_X_lstm, y=data_train_Y, epochs=200, batch_size=5000, verbose=1, validation_split =0.3, shuffle=True,
          callbacks=[callbacks.EarlyStopping(monitor='val_loss', patience=100,verbose=2, mode='auto')])
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1, 5)]            0
#
#  ConvL1 (TimeDistributed)    (None, 1, 128)            768
#
#  time_distributed (TimeDistr  (None, 1, 128)           512
#  ibuted)
#
#  ConvL2 (TimeDistributed)    (None, 1, 128)            16512
#
#  time_distributed_1 (TimeDis  (None, 1, 128)           512
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 1, 128)           0
#  tributed)
#
#  ConvL3 (TimeDistributed)    (None, 1, 64)             8256
#
#  time_distributed_3 (TimeDis  (None, 1, 64)            256
#  tributed)
#
#  ConvL4 (TimeDistributed)    (None, 1, 64)             4160
#
#  time_distributed_4 (TimeDis  (None, 1, 64)            256
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 1, 64)            0
#  tributed)
#
#  ConvL5 (TimeDistributed)    (None, 1, 32)             2080
#
#  time_distributed_6 (TimeDis  (None, 1, 32)            128
#  tributed)
#
#  ConvL6 (TimeDistributed)    (None, 1, 32)             1056
#
#  time_distributed_7 (TimeDis  (None, 1, 32)            128
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 1, 32)            0
#  tributed)
#
#  lstm (LSTM)                 (None, 1, 64)             24832
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  Dense1 (Dense)              (None, 32)                1056
#
#  Dense2 (Dense)              (None, 1)                 33
#
# =================================================================
# Total params: 72,961
# Trainable params: 72,065
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/200
# 56/56 [==============================] - 19s 200ms/step - loss: 0.8103 - val_loss: 0.4374
# Epoch 2/200
# 56/56 [==============================] - 10s 185ms/step - loss: 0.0346 - val_loss: 0.3650
# Epoch 3/200
# 56/56 [==============================] - 8s 144ms/step - loss: 0.0262 - val_loss: 0.2780
# Epoch 4/200
# 56/56 [==============================] - 12s 221ms/step - loss: 0.0215 - val_loss: 0.1340
# Epoch 5/200
# 56/56 [==============================] - 8s 143ms/step - loss: 0.0181 - val_loss: 0.0480
# Epoch 6/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0156 - val_loss: 0.0185
# Epoch 7/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0136 - val_loss: 0.0118
# Epoch 8/200
# 56/56 [==============================] - 8s 144ms/step - loss: 0.0122 - val_loss: 0.0082
# Epoch 9/200
# 56/56 [==============================] - 10s 175ms/step - loss: 0.0111 - val_loss: 0.0070
# Epoch 10/200
# 56/56 [==============================] - 10s 181ms/step - loss: 0.0102 - val_loss: 0.0068
# Epoch 11/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0094 - val_loss: 0.0066
# Epoch 12/200
# 56/56 [==============================] - 10s 176ms/step - loss: 0.0089 - val_loss: 0.0065
# Epoch 13/200
# 56/56 [==============================] - 10s 175ms/step - loss: 0.0083 - val_loss: 0.0065
# Epoch 14/200
# 56/56 [==============================] - 8s 149ms/step - loss: 0.0079 - val_loss: 0.0064
# Epoch 15/200
# 56/56 [==============================] - 10s 176ms/step - loss: 0.0075 - val_loss: 0.0063
# Epoch 16/200
# 56/56 [==============================] - 8s 151ms/step - loss: 0.0072 - val_loss: 0.0061
# Epoch 17/200
# 56/56 [==============================] - 9s 167ms/step - loss: 0.0068 - val_loss: 0.0057
# Epoch 18/200
# 56/56 [==============================] - 10s 175ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 19/200
# 56/56 [==============================] - 8s 143ms/step - loss: 0.0060 - val_loss: 0.0047
# Epoch 20/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0055 - val_loss: 0.0045
# Epoch 21/200
# 56/56 [==============================] - 11s 189ms/step - loss: 0.0051 - val_loss: 0.0044
# Epoch 22/200
# 56/56 [==============================] - 8s 143ms/step - loss: 0.0048 - val_loss: 0.0046
# Epoch 23/200
# 56/56 [==============================] - 10s 175ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 24/200
# 56/56 [==============================] - 10s 182ms/step - loss: 0.0043 - val_loss: 0.0039
# Epoch 25/200
# 56/56 [==============================] - 10s 175ms/step - loss: 0.0042 - val_loss: 0.0036
# Epoch 26/200
# 56/56 [==============================] - 12s 216ms/step - loss: 0.0040 - val_loss: 0.0035
# Epoch 27/200
# 56/56 [==============================] - 8s 144ms/step - loss: 0.0039 - val_loss: 0.0036
# Epoch 28/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 29/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 30/200
# 56/56 [==============================] - 8s 144ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 31/200
# 56/56 [==============================] - 10s 176ms/step - loss: 0.0036 - val_loss: 0.0040
# Epoch 32/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0035 - val_loss: 0.0041
# Epoch 33/200
# 56/56 [==============================] - 8s 144ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 34/200
# 56/56 [==============================] - 10s 175ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 35/200
# 56/56 [==============================] - 8s 150ms/step - loss: 0.0034 - val_loss: 0.0040
# Epoch 36/200
# 56/56 [==============================] - 9s 168ms/step - loss: 0.0033 - val_loss: 0.0041
# Epoch 37/200
# 56/56 [==============================] - 10s 176ms/step - loss: 0.0033 - val_loss: 0.0039
# Epoch 38/200
# 56/56 [==============================] - 8s 143ms/step - loss: 0.0032 - val_loss: 0.0039
# Epoch 39/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0032 - val_loss: 0.0036
# Epoch 40/200
# 56/56 [==============================] - 11s 189ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 41/200
# 56/56 [==============================] - 8s 143ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 42/200
# 56/56 [==============================] - 10s 176ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 43/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 44/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 45/200
# 56/56 [==============================] - 10s 176ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 46/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 47/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0028 - val_loss: 0.0029
# Epoch 48/200
# 56/56 [==============================] - 12s 212ms/step - loss: 0.0027 - val_loss: 0.0029
# Epoch 49/200
# 56/56 [==============================] - 8s 150ms/step - loss: 0.0027 - val_loss: 0.0028
# Epoch 50/200
# 56/56 [==============================] - 9s 168ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 51/200
# 56/56 [==============================] - 10s 176ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 52/200
# 56/56 [==============================] - 8s 144ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 53/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 54/200
# 56/56 [==============================] - 10s 187ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 55/200
# 56/56 [==============================] - 8s 142ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 56/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 57/200
# 56/56 [==============================] - 10s 181ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 58/200
# 56/56 [==============================] - 8s 143ms/step - loss: 0.0025 - val_loss: 0.0023
# Epoch 59/200
# 56/56 [==============================] - 10s 176ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 60/200
# 56/56 [==============================] - 10s 176ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 61/200
# 56/56 [==============================] - 8s 148ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 62/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 63/200
# 56/56 [==============================] - 9s 152ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 64/200
# 56/56 [==============================] - 9s 166ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 65/200
# 56/56 [==============================] - 10s 176ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 66/200
# 56/56 [==============================] - 8s 143ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 67/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 68/200
# 56/56 [==============================] - 10s 183ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 69/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 70/200
# 56/56 [==============================] - 12s 216ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 71/200
# 56/56 [==============================] - 8s 152ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 72/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 73/200
# 56/56 [==============================] - 11s 192ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 74/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 75/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 76/200
# 56/56 [==============================] - 10s 186ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 77/200
# 56/56 [==============================] - 8s 143ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 78/200
# 56/56 [==============================] - 10s 185ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 79/200
# 56/56 [==============================] - 10s 187ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 80/200
# 56/56 [==============================] - 8s 142ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 81/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 82/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 83/200
# 56/56 [==============================] - 8s 144ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 84/200
# 56/56 [==============================] - 10s 176ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 85/200
# 56/56 [==============================] - 10s 175ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 86/200
# 56/56 [==============================] - 8s 150ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 87/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 88/200
# 56/56 [==============================] - 8s 151ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 89/200
# 56/56 [==============================] - 9s 169ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 90/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 91/200
# 56/56 [==============================] - 8s 144ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 92/200
# 56/56 [==============================] - 12s 215ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 93/200
# 56/56 [==============================] - 9s 159ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 94/200
# 56/56 [==============================] - 9s 164ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 95/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 96/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 97/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 98/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 99/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 100/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 101/200
# 56/56 [==============================] - 9s 165ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 102/200
# 56/56 [==============================] - 9s 158ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 103/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 104/200
# 56/56 [==============================] - 9s 154ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 105/200
# 56/56 [==============================] - 10s 172ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 106/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 107/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 108/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 109/200
# 56/56 [==============================] - 10s 172ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 110/200
# 56/56 [==============================] - 9s 151ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 111/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 112/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 113/200
# 56/56 [==============================] - 9s 161ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 114/200
# 56/56 [==============================] - 12s 218ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 115/200
# 56/56 [==============================] - 8s 144ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 116/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 117/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 118/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 119/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 120/200
# 56/56 [==============================] - 10s 185ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 121/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 122/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 123/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 124/200
# 56/56 [==============================] - 8s 149ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 125/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 126/200
# 56/56 [==============================] - 10s 174ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 127/200
# 56/56 [==============================] - 9s 151ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 128/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 129/200
# 56/56 [==============================] - 8s 152ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 130/200
# 56/56 [==============================] - 9s 168ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 131/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 132/200
# 56/56 [==============================] - 8s 144ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 133/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 134/200
# 56/56 [==============================] - 9s 170ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 135/200
# 56/56 [==============================] - 9s 151ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 136/200
# 56/56 [==============================] - 12s 216ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 137/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 138/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 139/200
# 56/56 [==============================] - 11s 199ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 140/200
# 56/56 [==============================] - 8s 152ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 141/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 142/200
# 56/56 [==============================] - 11s 198ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 143/200
# 56/56 [==============================] - 8s 144ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 144/200
# 56/56 [==============================] - 10s 184ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 145/200
# 56/56 [==============================] - 10s 172ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 146/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 147/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 148/200
# 56/56 [==============================] - 8s 151ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 149/200
# 56/56 [==============================] - 9s 168ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 150/200
# 56/56 [==============================] - 10s 176ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 151/200
# 56/56 [==============================] - 8s 144ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 152/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 153/200
# 56/56 [==============================] - 10s 187ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 154/200
# 56/56 [==============================] - 8s 147ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 155/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 156/200
# 56/56 [==============================] - 10s 185ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 157/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 158/200
# 56/56 [==============================] - 12s 211ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 159/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 160/200
# 56/56 [==============================] - 8s 149ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 161/200
# 56/56 [==============================] - 10s 181ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 162/200
# 56/56 [==============================] - 11s 192ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 163/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 164/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 165/200
# 56/56 [==============================] - 11s 190ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 166/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 167/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 168/200
# 56/56 [==============================] - 11s 192ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 169/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 170/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 171/200
# 56/56 [==============================] - 9s 167ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 172/200
# 56/56 [==============================] - 9s 155ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 173/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 174/200
# 56/56 [==============================] - 9s 154ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 175/200
# 56/56 [==============================] - 10s 172ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 176/200
# 56/56 [==============================] - 10s 188ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 177/200
# 56/56 [==============================] - 8s 147ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 178/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 179/200
# 56/56 [==============================] - 10s 181ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 180/200
# 56/56 [==============================] - 11s 204ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 181/200
# 56/56 [==============================] - 9s 157ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 182/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 183/200
# 56/56 [==============================] - 9s 154ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 184/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 185/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 186/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 187/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 188/200
# 56/56 [==============================] - 11s 199ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 189/200
# 56/56 [==============================] - 8s 149ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 190/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 191/200
# 56/56 [==============================] - 11s 198ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 192/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 193/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 194/200
# 56/56 [==============================] - 11s 193ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 195/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 196/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 197/200
# 56/56 [==============================] - 11s 191ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 198/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 199/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 200/200
# 56/56 [==============================] - 10s 187ms/step - loss: 0.0015 - val_loss: 0.0017

# %% [markdown]
# ####Prediction of the track bed on training data

# %%
y_pred_train = model.predict(data_train_X_lstm)
# Out:
# 12398/12398 [==============================] - 33s 3ms/step

# %%
y_pred_train.shape, data_train_Y.shape
# Out:
# ((396734, 1), (396734, 1))

# %%
train_Predict_full_range = scaler_Y.inverse_transform(y_pred_train)
data_train_Y_full_range = scaler_Y.inverse_transform(data_train_Y)

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error

print('RMSE:',np.sqrt(mean_squared_error(data_train_Y_full_range, train_Predict_full_range)))
print('RMSE Percentage:',rmspe(data_train_Y_full_range, train_Predict_full_range))
print('RMSE Percentage-1:',rmspe_1(data_train_Y_full_range, train_Predict_full_range))
print('Mean Absolute Error:', mean_absolute_error(data_train_Y_full_range, train_Predict_full_range))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(data_train_Y_full_range, train_Predict_full_range))
print('R^2 Score:', r2_score(data_train_Y_full_range, train_Predict_full_range))
# Out:
# RMSE: 90.06830122334935
# RMSE Percentage: 12663.121085843695
# RMSE Percentage-1: nan
# Mean Absolute Error: 65.17893233568367
# Mean Absolute Percentage Error: 1.487743732754731
# R^2 Score: 0.7771224702023769
# <ipython-input-4-aa62cd6b9d47>:2: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.nanmean(np.square(y_true - y_pred) / y_true))*100

# %%
import matplotlib.pyplot as plt

plt.subplots(figsize=(15, 5))

plt.plot(data_train_Y_full_range, color='red', label="Ground Truth") # Y_test_given,y_pred_test
plt.plot(train_Predict_full_range, color='blue', label="Prediction")
plt.ylabel("Ice Bed Height")
plt.xlabel("Data Elements")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ####Prediction of track bed on test data

# %%
y_predict_test = model.predict(data_test_X_lstm)
# Out:
# 7375/7375 [==============================] - 23s 3ms/step

# %%
data_test_Y.shape, y_predict_test.shape
# Out:
# ((235972, 1), (235972, 1))

# %%
test_Predict_full_range = scaler_Y.inverse_transform(y_predict_test)
data_test_Y_full_range = scaler_Y.inverse_transform(data_test_Y)

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error

print('RMSE:',np.sqrt(mean_squared_error(data_test_Y_full_range, test_Predict_full_range)))
print('RMSE Percentage:',rmspe(data_test_Y_full_range, test_Predict_full_range))
print('RMSE Percentage-1:',rmspe_1(data_test_Y_full_range, test_Predict_full_range))
print('Mean Absolute Error:', mean_absolute_error(data_test_Y_full_range, test_Predict_full_range))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(data_test_Y_full_range, test_Predict_full_range))
print('R^2 Score:', r2_score(data_test_Y_full_range, test_Predict_full_range))
# Out:
# RMSE: 145.36615167115914
# RMSE Percentage: 14022.487479037789
# RMSE Percentage-1: 216.34390298652568
# Mean Absolute Error: 103.56804233363724
# Mean Absolute Percentage Error: 1.6485242514535408
# R^2 Score: 0.0005496676859118033

# %%
import matplotlib.pyplot as plt

plt.subplots(figsize=(15, 5))

plt.plot(data_test_Y_full_range, color='red', label="Ground Truth") # Y_test_given,y_pred_test
plt.plot(test_Predict_full_range, color='blue', label="Prediction")
plt.ylabel("Ice Bed Height")
plt.xlabel("Data Elements")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# #### Prediction of ice bed height on 1201x1201 grid data

# %%
y_Predict_1201 = model.predict(data_1201_X_lstm)
# Out:
# 45076/45076 [==============================] - 142s 3ms/step

# %%
y_Predict_1201.shape
# Out:
# (1442401, 1)

# %%
y_Predict_1201_full = scaler_Y.inverse_transform(y_Predict_1201)

# %%
y_Predict_1201_full_flatten=y_Predict_1201_full.flatten()

# %%
prediction_on_1201_2D=y_Predict_1201_full_flatten.reshape(1201,1201)
prediction_on_1201_2D.shape
# Out:
# (1201, 1201)

# %%
new_filename_2 = '/content/drive/MyDrive/Ice-bed_dataset/ice_bed_prediction_1201_Dense_LSTM.h5'

with h5py.File(new_filename_2, 'w') as hf:
    hf.create_dataset("track bed prediction",  data=prediction_on_1201_2D)

# %%
import matplotlib.pyplot as plt
plt.imshow(np.transpose(prediction_on_1201_2D), cmap="jet")

plt.title('Track Bed Prediction')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.gca().invert_yaxis()
plt.colorbar(label="Color-bar", orientation="horizontal")

# %% [markdown]
# ## New Interpolation Data

# %%
n_training_data = pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/new_interpolated_track_bed_training.csv')
n_testing_data = pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/new_interpotaled_track_bed_testing.csv')
n_df_pred = pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/y_test.csv')
n_data_1201 = pd.read_csv('/content/drive/MyDrive/Ice-bed_dataset/df_1201.csv')
n_test_data_1201 = n_data_1201.drop(['Unnamed: 0','surf_x', 'surf_y'],axis=1)

# %%
n_training_data
# Out:
#         Unnamed: 0         surf_x       surf_y  track_bed_target     surf_vx  \
# 0                0 -206037.406250 -1827384.000        538.235168 -102.379379
# 1                1 -205981.171875 -1827518.625        550.491638 -101.973237
# 2                2 -205953.109375 -1827586.125        563.800598 -101.784982
# 3                3 -205897.078125 -1827720.750        560.530823 -101.493970
# 4                4 -205841.328125 -1827855.625        545.708252 -101.271730
# ...            ...            ...          ...               ...         ...
# 396729      396729 -278061.656250 -1720043.625        240.890564 -105.011937
# 396730      396730 -278064.468750 -1720023.125        240.956131 -105.014680
# 396731      396731 -278067.125000 -1720001.375        233.992737 -105.020867
# 396732      396732 -278069.656250 -1719980.875        227.039673 -105.026963
# 396733      396733 -278072.343750 -1719959.250        227.064072 -105.033698
#
#          surf_vy  surf_dhdt  surf_SMB     surf_elv
# 0       2.455286  -0.197761  0.300519  1873.835128
# 1       2.884405  -0.197749  0.300364  1874.221764
# 2       2.952367  -0.197750  0.300285  1874.520200
# 3       2.288839  -0.197765  0.300125  1874.620712
# 4       1.235018  -0.197797  0.299963  1875.128108
# ...          ...        ...       ...          ...
# 396729 -4.932849  -0.403757  0.144332  1347.292140
# 396730 -4.937994  -0.403847  0.144088  1347.204583
# 396731 -4.940966  -0.403939  0.143831  1347.069799
# 396732 -4.945610  -0.404026  0.143588  1346.941386
# 396733 -4.952594  -0.404118  0.143332  1346.804583
#
# [396734 rows x 9 columns]

# %%
n_testing_data
# Out:
#         Unnamed: 0         surf_x        surf_y     surf_vx    surf_vy  \
# 0                0 -220038.295520 -1.697568e+06  -81.469318   1.026504
# 1                1 -220038.408158 -1.697642e+06  -81.479483   1.088446
# 2                2 -220038.646540 -1.697789e+06  -81.490122   1.216577
# 3                3 -220038.939782 -1.697936e+06  -81.488490   1.350560
# 4                4 -220039.334272 -1.698083e+06  -81.506943   1.358371
# ...            ...            ...           ...         ...        ...
# 235967      235967 -241867.395118 -1.871682e+06 -109.036689  30.657134
# 235968      235968 -241879.313090 -1.871664e+06 -109.227077  30.716942
# 235969      235969 -241890.904137 -1.871645e+06 -109.397180  30.763926
# 235970      235970 -242055.253924 -1.871391e+06 -111.142185  31.286631
# 235971      235971 -242066.841155 -1.871373e+06 -111.234107  31.316871
#
#         surf_dhdt  surf_SMB     surf_elv
# 0       -0.003840  0.374337  1862.341442
# 1       -0.003898  0.374307  1862.340283
# 2       -0.004015  0.374246  1862.337831
# 3       -0.004132  0.374184  1862.310339
# 4       -0.004249  0.374122  1862.314235
# ...           ...       ...          ...
# 235967  -0.411423 -0.017839  1556.905320
# 235968  -0.411860 -0.017826  1556.788316
# 235969  -0.412292 -0.017803  1556.660822
# 235970  -0.418384 -0.016967  1555.680990
# 235971  -0.418821 -0.016881  1555.653762
#
# [235972 rows x 8 columns]

# %%
n_training_data = n_training_data.drop(['Unnamed: 0','surf_x', 'surf_y'],axis=1)
n_testing_data = n_testing_data.drop(['Unnamed: 0','surf_x', 'surf_y'],axis=1)

# %%
n_training_data.shape, n_testing_data.shape, n_test_data_1201.shape
# Out:
# ((396734, 6), (235972, 5), (1442401, 5))

# %%
n_training_data.keys(), n_testing_data.keys(), n_test_data_1201.keys()
# Out:
# (Index(['track_bed_target', 'surf_vx', 'surf_vy', 'surf_dhdt', 'surf_SMB',
#         'surf_elv'],
#        dtype='object'),
#  Index(['surf_vx', 'surf_vy', 'surf_dhdt', 'surf_SMB', 'surf_elv'], dtype='object'),
#  Index(['surf_vx', 'surf_vy', 'surf_dhdt', 'surf_SMB', 'surf_elv'], dtype='object'))

# %%
n_x1_train = n_training_data.iloc[:,1:]
n_y1_train = n_training_data.iloc[:,0:1]
n_X_test_given = n_testing_data.iloc[:,:]
n_Y_test_given = n_df_pred.iloc[:,:]

# %% [markdown]
# ### Plot dataset before normalization:

# %%
#n_x1_train.boxplot(), n_X_test_given.boxplot(), n_test_data_1201.boxplot()

import numpy as np
import matplotlib.pyplot as plt

labels = ['surf_vx', 'surf_vy', 'surf_dhdt', 'surf_SMB', 'surf_elv']

#MultipleBoxplot
plt.figure(figsize=(20,6))

plt.subplot(1, 3, 1)
plt.ylim([-700, 2700])
plt.boxplot(n_x1_train, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : New Training Data')


plt.subplot(1, 3, 2)
plt.ylim([-700, 2700])
plt.boxplot(n_X_test_given, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : New Testing Data')


plt.subplot(1, 3, 3)
plt.ylim([-700, 2700])
plt.boxplot(n_test_data_1201, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : 1201x1201 Grid Data')

plt.tight_layout()
plt.show()

# %%
n_x1_train.shape, n_X_test_given.shape, n_test_data_1201.shape
# Out:
# ((396734, 5), (235972, 5), (1442401, 5))

# %%
n_all_X = np.concatenate((n_x1_train, n_X_test_given, n_test_data_1201), axis=0)
n_all_X.shape
# Out:
# (2075107, 5)

# %%
n_y1_train.shape, n_Y_test_given.shape
# Out:
# ((396734, 1), (235972, 1))

# %%
n_all_Y = np.concatenate((n_y1_train, n_Y_test_given), axis=0)
n_all_Y.shape
# Out:
# (632706, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_X = MinMaxScaler(feature_range=(0, 1))
scaler_Y = MinMaxScaler(feature_range=(0, 1))

n_all_X_nor = scaler_X.fit_transform(n_all_X)
n_all_Y_nor = scaler_Y.fit_transform(n_all_Y)

# %%
n_all_X_nor.shape, n_all_Y_nor.shape
# Out:
# ((2075107, 5), (632706, 1))

# %% [markdown]
# ### Normalize dataset to bring all variables in the range of [0, 1]:

# %%
#seperate the dependent and independent variable for train, test, and 1201 dataset
n_data_train_X = n_all_X_nor[0:396734, :]
n_data_train_Y = n_all_Y_nor[0:396734, :]
n_data_test_X = n_all_X_nor[396734:632706, :]
n_data_test_Y = n_all_Y_nor[396734:, :]
n_data_1201_X = n_all_X_nor[632706:, :]

# %% [markdown]
# ### Plot dataset after normalization:

# %%
#pd.DataFrame.from_records(n_data_train_X).boxplot(), pd.DataFrame.from_records(n_data_test_X).boxplot(), pd.DataFrame.from_records(n_data_1201_X).boxplot()

import numpy as np
import matplotlib.pyplot as plt

labels = ['surf_vx', 'surf_vy', 'surf_dhdt', 'surf_SMB', 'surf_elv']

#MultipleBoxplot
plt.figure(figsize=(20,6))

plt.subplot(1, 3, 1)
plt.ylim([-0.1, 1.1])
plt.boxplot(n_data_train_X, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : New Training Data')


plt.subplot(1, 3, 2)
plt.ylim([-0.1, 1.1])
plt.boxplot(n_data_test_X, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : New Testing Data')


plt.subplot(1, 3, 3)
plt.ylim([-0.1, 1.1])
plt.boxplot(n_data_1201_X, vert=True, patch_artist=True, labels=labels)
plt.ylabel('observed value')
plt.title('Box Plot : 1201x1201 Grid Data')


plt.tight_layout()
plt.show()

# %%
n_data_train_X_lstm = n_data_train_X.reshape(n_data_train_X.shape[0], 1, n_data_train_X.shape[1])
n_data_train_X_lstm.shape
# Out:
# (396734, 1, 5)

# %%
n_data_test_X_lstm = n_data_test_X.reshape(n_data_test_X.shape[0], 1, n_data_test_X.shape[1])
n_data_test_X_lstm.shape
# Out:
# (235972, 1, 5)

# %%
n_data_1201_X_lstm = n_data_1201_X.reshape(n_data_1201_X.shape[0], 1, n_data_1201_X.shape[1])
n_data_1201_X_lstm.shape
# Out:
# (1442401, 1, 5)

# %% [markdown]
# ### Training model using new interpolation data

# %%
import keras,os
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten, Dropout, AveragePooling2D, LSTM, Activation, ConvLSTM2D, TimeDistributed, Input, Reshape
from keras.layers import UpSampling1D, Conv2DTranspose, UpSampling2D, BatchNormalization
from tensorflow.keras import callbacks
import numpy as np

def get_model(input_dims):
  input_batch = Input(shape = input_dims)

  conv_model = TimeDistributed(Dense(128, activation="sigmoid"), name='ConvL1')(input_batch)
  conv_model = TimeDistributed(BatchNormalization())(conv_model)
  conv_model = TimeDistributed(Dense(128, activation="sigmoid"), name='ConvL2' )(conv_model)
  conv_model = TimeDistributed(BatchNormalization())(conv_model)
  conv_model = TimeDistributed(Dropout(0.5))(conv_model)
  conv_model = TimeDistributed(Dense(64, activation="sigmoid"), name='ConvL3' )(conv_model)
  conv_model = TimeDistributed(BatchNormalization())(conv_model)
  conv_model = TimeDistributed(Dense(64, activation="sigmoid"), name='ConvL4' )(conv_model)
  conv_model = TimeDistributed(BatchNormalization())(conv_model)
  conv_model = TimeDistributed(Dropout(0.5))(conv_model)
  conv_model = TimeDistributed(Dense(32, activation="sigmoid"), name='ConvL5' )(conv_model)
  conv_model = TimeDistributed(BatchNormalization())(conv_model)
  conv_model = TimeDistributed(Dense(32, activation="sigmoid"), name='ConvL6' )(conv_model)
  conv_model = TimeDistributed(BatchNormalization())(conv_model)
  conv_model = TimeDistributed(Dropout(0.5))(conv_model)

  lstm_network = LSTM(64, return_sequences=True)(conv_model)
  lstm_network = keras.layers.LSTM(32, return_sequences=False)(lstm_network)
  lstm_network = Dropout(0.5)(lstm_network)
  lstm_network = keras.layers.Dense(32, activation='sigmoid', name='Dense1')(lstm_network)
  lstm_network = keras.layers.Dense(1, activation='linear', name='Dense2')(lstm_network)

  encoder = Model(inputs=input_batch, outputs=lstm_network, name='encoder')

  return encoder

# %%
n_model = get_model(n_data_train_X_lstm.shape[1:])
n_model.summary()
n_model.compile(optimizer='adam', loss='mse')
n_model.fit(n_data_train_X_lstm, y=n_data_train_Y, epochs=200, batch_size=5000, verbose=1, validation_split =0.3, shuffle=True,
          callbacks=[callbacks.EarlyStopping(monitor='val_loss', patience=100,verbose=2, mode='auto')])
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 1, 5)]            0
#
#  ConvL1 (TimeDistributed)    (None, 1, 128)            768
#
#  time_distributed_63 (TimeDi  (None, 1, 128)           512
#  stributed)
#
#  ConvL2 (TimeDistributed)    (None, 1, 128)            16512
#
#  time_distributed_64 (TimeDi  (None, 1, 128)           512
#  stributed)
#
#  time_distributed_65 (TimeDi  (None, 1, 128)           0
#  stributed)
#
#  ConvL3 (TimeDistributed)    (None, 1, 64)             8256
#
#  time_distributed_66 (TimeDi  (None, 1, 64)            256
#  stributed)
#
#  ConvL4 (TimeDistributed)    (None, 1, 64)             4160
#
#  time_distributed_67 (TimeDi  (None, 1, 64)            256
#  stributed)
#
#  time_distributed_68 (TimeDi  (None, 1, 64)            0
#  stributed)
#
#  ConvL5 (TimeDistributed)    (None, 1, 32)             2080
#
#  time_distributed_69 (TimeDi  (None, 1, 32)            128
#  stributed)
#
#  ConvL6 (TimeDistributed)    (None, 1, 32)             1056
#
#  time_distributed_70 (TimeDi  (None, 1, 32)            128
#  stributed)
#
#  time_distributed_71 (TimeDi  (None, 1, 32)            0
#  stributed)
#
#  lstm_14 (LSTM)              (None, 1, 64)             24832
#
#  lstm_15 (LSTM)              (None, 32)                12416
#
#  dropout_31 (Dropout)        (None, 32)                0
#
#  Dense1 (Dense)              (None, 32)                1056
#
#  Dense2 (Dense)              (None, 1)                 33
#
# =================================================================
# Total params: 72,961
# Trainable params: 72,065
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/200
# 56/56 [==============================] - 20s 231ms/step - loss: 0.0911 - val_loss: 0.0145
# Epoch 2/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0064 - val_loss: 0.0095
# Epoch 3/200
# 56/56 [==============================] - 9s 164ms/step - loss: 0.0053 - val_loss: 0.0083
# Epoch 4/200
# 56/56 [==============================] - 9s 159ms/step - loss: 0.0046 - val_loss: 0.0078
# Epoch 5/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0042 - val_loss: 0.0077
# Epoch 6/200
# 56/56 [==============================] - 9s 153ms/step - loss: 0.0038 - val_loss: 0.0083
# Epoch 7/200
# 56/56 [==============================] - 10s 169ms/step - loss: 0.0035 - val_loss: 0.0089
# Epoch 8/200
# 56/56 [==============================] - 11s 189ms/step - loss: 0.0033 - val_loss: 0.0095
# Epoch 9/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0032 - val_loss: 0.0087
# Epoch 10/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0030 - val_loss: 0.0064
# Epoch 11/200
# 56/56 [==============================] - 11s 191ms/step - loss: 0.0029 - val_loss: 0.0049
# Epoch 12/200
# 56/56 [==============================] - 9s 157ms/step - loss: 0.0028 - val_loss: 0.0045
# Epoch 13/200
# 56/56 [==============================] - 10s 185ms/step - loss: 0.0028 - val_loss: 0.0042
# Epoch 14/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0027 - val_loss: 0.0040
# Epoch 15/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0026 - val_loss: 0.0036
# Epoch 16/200
# 56/56 [==============================] - 11s 205ms/step - loss: 0.0026 - val_loss: 0.0035
# Epoch 17/200
# 56/56 [==============================] - 10s 185ms/step - loss: 0.0026 - val_loss: 0.0032
# Epoch 18/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0025 - val_loss: 0.0030
# Epoch 19/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0025 - val_loss: 0.0029
# Epoch 20/200
# 56/56 [==============================] - 11s 191ms/step - loss: 0.0025 - val_loss: 0.0029
# Epoch 21/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 22/200
# 56/56 [==============================] - 10s 181ms/step - loss: 0.0024 - val_loss: 0.0029
# Epoch 23/200
# 56/56 [==============================] - 10s 172ms/step - loss: 0.0024 - val_loss: 0.0027
# Epoch 24/200
# 56/56 [==============================] - 9s 154ms/step - loss: 0.0024 - val_loss: 0.0029
# Epoch 25/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0024 - val_loss: 0.0026
# Epoch 26/200
# 56/56 [==============================] - 10s 181ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 27/200
# 56/56 [==============================] - 11s 189ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 28/200
# 56/56 [==============================] - 10s 182ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 29/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0023 - val_loss: 0.0028
# Epoch 30/200
# 56/56 [==============================] - 8s 148ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 31/200
# 56/56 [==============================] - 10s 181ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 32/200
# 56/56 [==============================] - 11s 197ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 33/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 34/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 35/200
# 56/56 [==============================] - 11s 195ms/step - loss: 0.0022 - val_loss: 0.0025
# Epoch 36/200
# 56/56 [==============================] - 8s 147ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 37/200
# 56/56 [==============================] - 10s 187ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 38/200
# 56/56 [==============================] - 11s 200ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 39/200
# 56/56 [==============================] - 9s 155ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 40/200
# 56/56 [==============================] - 10s 181ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 41/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 42/200
# 56/56 [==============================] - 9s 155ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 43/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 44/200
# 56/56 [==============================] - 10s 174ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 45/200
# 56/56 [==============================] - 9s 153ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 46/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 47/200
# 56/56 [==============================] - 10s 186ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 48/200
# 56/56 [==============================] - 8s 147ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 49/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 50/200
# 56/56 [==============================] - 10s 184ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 51/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 52/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 53/200
# 56/56 [==============================] - 13s 232ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 54/200
# 56/56 [==============================] - 9s 156ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 55/200
# 56/56 [==============================] - 10s 181ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 56/200
# 56/56 [==============================] - 10s 181ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 57/200
# 56/56 [==============================] - 8s 147ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 58/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 59/200
# 56/56 [==============================] - 11s 190ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 60/200
# 56/56 [==============================] - 8s 148ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 61/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 62/200
# 56/56 [==============================] - 11s 190ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 63/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 64/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 65/200
# 56/56 [==============================] - 9s 167ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 66/200
# 56/56 [==============================] - 9s 154ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 67/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 68/200
# 56/56 [==============================] - 9s 152ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 69/200
# 56/56 [==============================] - 9s 169ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 70/200
# 56/56 [==============================] - 10s 177ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 71/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 72/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 73/200
# 56/56 [==============================] - 10s 175ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 74/200
# 56/56 [==============================] - 9s 157ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 75/200
# 56/56 [==============================] - 10s 181ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 76/200
# 56/56 [==============================] - 11s 191ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 77/200
# 56/56 [==============================] - 8s 152ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 78/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 79/200
# 56/56 [==============================] - 10s 184ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 80/200
# 56/56 [==============================] - 10s 183ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 81/200
# 56/56 [==============================] - 10s 181ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 82/200
# 56/56 [==============================] - 8s 147ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 83/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 84/200
# 56/56 [==============================] - 11s 196ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 85/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 86/200
# 56/56 [==============================] - 10s 186ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 87/200
# 56/56 [==============================] - 11s 200ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 88/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 89/200
# 56/56 [==============================] - 10s 182ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 90/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 91/200
# 56/56 [==============================] - 9s 155ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 92/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 93/200
# 56/56 [==============================] - 11s 189ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 94/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 95/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 96/200
# 56/56 [==============================] - 10s 187ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 97/200
# 56/56 [==============================] - 8s 144ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 98/200
# 56/56 [==============================] - 10s 187ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 99/200
# 56/56 [==============================] - 11s 190ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 100/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 101/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 102/200
# 56/56 [==============================] - 10s 188ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 103/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 104/200
# 56/56 [==============================] - 10s 186ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 105/200
# 56/56 [==============================] - 11s 192ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 106/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 107/200
# 56/56 [==============================] - 10s 172ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 108/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 109/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 110/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 111/200
# 56/56 [==============================] - 10s 175ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 112/200
# 56/56 [==============================] - 8s 149ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 113/200
# 56/56 [==============================] - 10s 181ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 114/200
# 56/56 [==============================] - 9s 160ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 115/200
# 56/56 [==============================] - 9s 163ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 116/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 117/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 118/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 119/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 120/200
# 56/56 [==============================] - 8s 147ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 121/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 122/200
# 56/56 [==============================] - 9s 170ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 123/200
# 56/56 [==============================] - 9s 154ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 124/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 125/200
# 56/56 [==============================] - 9s 152ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 126/200
# 56/56 [==============================] - 10s 170ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 127/200
# 56/56 [==============================] - 10s 186ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 128/200
# 56/56 [==============================] - 8s 147ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 129/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 130/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 131/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 132/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 133/200
# 56/56 [==============================] - 12s 216ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 134/200
# 56/56 [==============================] - 8s 147ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 135/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 136/200
# 56/56 [==============================] - 10s 184ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 137/200
# 56/56 [==============================] - 8s 149ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 138/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 139/200
# 56/56 [==============================] - 10s 188ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 140/200
# 56/56 [==============================] - 8s 148ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 141/200
# 56/56 [==============================] - 10s 183ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 142/200
# 56/56 [==============================] - 11s 191ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 143/200
# 56/56 [==============================] - 8s 148ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 144/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 145/200
# 56/56 [==============================] - 10s 173ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 146/200
# 56/56 [==============================] - 9s 151ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 147/200
# 56/56 [==============================] - 10s 181ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 148/200
# 56/56 [==============================] - 10s 181ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 149/200
# 56/56 [==============================] - 9s 152ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 150/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 151/200
# 56/56 [==============================] - 10s 183ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 152/200
# 56/56 [==============================] - 8s 147ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 153/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 154/200
# 56/56 [==============================] - 10s 182ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 155/200
# 56/56 [==============================] - 8s 147ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 156/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 157/200
# 56/56 [==============================] - 10s 183ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 158/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 159/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 160/200
# 56/56 [==============================] - 11s 206ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 161/200
# 56/56 [==============================] - 9s 156ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 162/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 163/200
# 56/56 [==============================] - 8s 151ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 164/200
# 56/56 [==============================] - 10s 171ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 165/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 166/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 167/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 168/200
# 56/56 [==============================] - 11s 194ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 169/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 170/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 171/200
# 56/56 [==============================] - 11s 191ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 172/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 173/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 174/200
# 56/56 [==============================] - 11s 190ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 175/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 176/200
# 56/56 [==============================] - 10s 180ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 177/200
# 56/56 [==============================] - 11s 192ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 178/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 179/200
# 56/56 [==============================] - 10s 176ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 180/200
# 56/56 [==============================] - 9s 167ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 181/200
# 56/56 [==============================] - 9s 154ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 182/200
# 56/56 [==============================] - 10s 178ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 183/200
# 56/56 [==============================] - 9s 154ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 184/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 185/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 186/200
# 56/56 [==============================] - 8s 144ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 187/200
# 56/56 [==============================] - 12s 212ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 188/200
# 56/56 [==============================] - 10s 183ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 189/200
# 56/56 [==============================] - 9s 153ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 190/200
# 56/56 [==============================] - 10s 170ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 191/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 192/200
# 56/56 [==============================] - 8s 145ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 193/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 194/200
# 56/56 [==============================] - 11s 193ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 195/200
# 56/56 [==============================] - 8s 146ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 196/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 197/200
# 56/56 [==============================] - 10s 170ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 198/200
# 56/56 [==============================] - 9s 152ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 199/200
# 56/56 [==============================] - 10s 179ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 200/200
# 56/56 [==============================] - 9s 159ms/step - loss: 0.0013 - val_loss: 0.0015

# %% [markdown]
# ####Prediction of the track bed on new training data

# %%
n_y_pred_train = n_model.predict(n_data_train_X_lstm)
# Out:
# 12398/12398 [==============================] - 38s 3ms/step

# %%
n_y_pred_train.shape, n_data_train_Y.shape
# Out:
# ((396734, 1), (396734, 1))

# %%
n_train_Predict_full_range = scaler_Y.inverse_transform(n_y_pred_train)
n_data_train_Y_full_range = scaler_Y.inverse_transform(n_data_train_Y)

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error

print('RMSE:',np.sqrt(mean_squared_error(n_data_train_Y_full_range, n_train_Predict_full_range)))
print('RMSE Percentage:',rmspe(n_data_train_Y_full_range, n_train_Predict_full_range))
print('RMSE Percentage-1:',rmspe_1(n_data_train_Y_full_range, n_train_Predict_full_range))
print('Mean Absolute Error:', mean_absolute_error(n_data_train_Y_full_range, n_train_Predict_full_range))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(n_data_train_Y_full_range, n_train_Predict_full_range))
print('R^2 Score:', r2_score(n_data_train_Y_full_range, n_train_Predict_full_range))
# Out:
# RMSE: 204.06946063065308
# RMSE Percentage: 28573.25022215273
# RMSE Percentage-1: 870.5397370157444
# Mean Absolute Error: 162.9108620743244
# Mean Absolute Percentage Error: 3.86233630817245
# R^2 Score: -0.14413790984437713

# %%
import matplotlib.pyplot as plt

plt.subplots(figsize=(15, 5))

plt.plot(n_data_train_Y_full_range, color='red', label="Ground Truth") # Y_test_given,y_pred_test
plt.plot(n_train_Predict_full_range, color='blue', label="Prediction")
plt.ylabel("Ice Bed Height")
plt.xlabel("Data Elements")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ####Prediction of track bed on new test data

# %%
n_y_predict_test = n_model.predict(n_data_test_X_lstm)
# Out:
# 7375/7375 [==============================] - 23s 3ms/step

# %%
n_data_test_Y.shape, n_y_predict_test.shape
# Out:
# ((235972, 1), (235972, 1))

# %%
n_test_Predict_full_range = scaler_Y.inverse_transform(n_y_predict_test)
n_data_test_Y_full_range = scaler_Y.inverse_transform(n_data_test_Y)

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error

print('RMSE:',np.sqrt(mean_squared_error(n_data_test_Y_full_range, n_test_Predict_full_range)))
print('RMSE Percentage:',rmspe(n_data_test_Y_full_range, n_test_Predict_full_range))
print('RMSE Percentage-1:',rmspe_1(n_data_test_Y_full_range, n_test_Predict_full_range))
print('Mean Absolute Error:', mean_absolute_error(n_data_test_Y_full_range, n_test_Predict_full_range))
print('Mean Absolute Percentage Error:', mean_absolute_percentage_error(n_data_test_Y_full_range, n_test_Predict_full_range))
print('R^2 Score:', r2_score(n_data_test_Y_full_range, n_test_Predict_full_range))
# Out:
# RMSE: 144.8754611538137
# RMSE Percentage: 13555.989461999201
# RMSE Percentage-1: nan
# Mean Absolute Error: 107.86473032561469
# Mean Absolute Percentage Error: 1.5782393929626146
# R^2 Score: 0.007285666064620555
# <ipython-input-4-aa62cd6b9d47>:2: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.nanmean(np.square(y_true - y_pred) / y_true))*100

# %%
import matplotlib.pyplot as plt

plt.subplots(figsize=(15, 5))

plt.plot(n_data_test_Y_full_range, color='red', label="Ground Truth") # Y_test_given,y_pred_test
plt.plot(n_test_Predict_full_range, color='blue', label="Prediction")
plt.ylabel("Ice Bed Height")
plt.xlabel("Data Elements")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# #### Prediction of ice bed height on 1201x1201 grid data

# %%
n_y_Predict_1201 = n_model.predict(n_data_1201_X_lstm)
# Out:
# 45076/45076 [==============================] - 165s 4ms/step

# %%
n_y_Predict_1201.shape
# Out:
# (1442401, 1)

# %%
n_y_Predict_1201_full = scaler_Y.inverse_transform(n_y_Predict_1201)

# %%
n_y_Predict_1201_full_flatten=n_y_Predict_1201_full.flatten()

# %%
n_prediction_on_1201_2D=n_y_Predict_1201_full_flatten.reshape(1201,1201)
n_prediction_on_1201_2D.shape
# Out:
# (1201, 1201)

# %%
new_filename_2 = '/content/drive/MyDrive/Ice-bed_dataset/ice_bed_prediction_1201_Dense_LSTM_new.h5'

with h5py.File(new_filename_2, 'w') as hf:
    hf.create_dataset("track bed prediction",  data=n_prediction_on_1201_2D)

# %%
import matplotlib.pyplot as plt
plt.imshow(np.transpose(n_prediction_on_1201_2D), cmap="jet")

plt.title('Track Bed Prediction')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.gca().invert_yaxis()
plt.colorbar(label="Color-bar", orientation="horizontal")
